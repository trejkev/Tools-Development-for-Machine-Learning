# %% [markdown]
# # Exploratory Data Analysis of Top 250 movies on Internet Movie Database (IMDb)
#
# ### Made by: Kevin Trejos Vargas and Rene Quesada

# %% [markdown]
# ## **Univariate Analysis**

# %%
# prompt: give the code to read the IMDB Top 250 Movies.csv and parse with numpy

import numpy as np
import pandas as pd

# Read the IMDB Top 250 Movies.csv file into a Pandas DataFrame
df = pd.read_csv('/content/sample_data/IMDB Top 250 Movies.csv')
print(df.count)
# Parse a copy of the DataFrame with NumPy
df_with_arrays= df[:]

# Splitting the 'genre' column by comma and expanding it into multiple columns
genres = df['genre'].str.split(',', expand=True)

# Adding a prefix to each column
genres = genres.add_prefix('genre_')

# Splitting the 'genre' column by comma and expanding it into multiple columns
writers = df['writers'].str.split(',', expand=True)

# Adding a prefix to each column
writers = writers.add_prefix('writers_')

# Splitting the 'genre' column by comma and expanding it into multiple columns
casts = df['casts'].str.split(',', expand=True)

# Adding a prefix to each column
casts = casts.add_prefix('casts_')

# Splitting the 'genre' column by comma and expanding it into multiple columns
directors = df['directors'].str.split(',', expand=True)

# Adding a prefix to each column
directors = directors.add_prefix('directors_')

# Concatenating the new genre columns with the original DataFrame
df_with_arrays = pd.concat([df_with_arrays, genres], axis=1)

# Concatenating the new genre columns with the original DataFrame
df_with_arrays = pd.concat([df_with_arrays, writers], axis=1)

# Concatenating the new genre columns with the original DataFrame
df_with_arrays = pd.concat([df_with_arrays, casts], axis=1)

# Concatenating the new genre columns with the original DataFrame
df_with_arrays = pd.concat([df_with_arrays, directors], axis=1)

# Print the data
#print(df.head())
print(df_with_arrays.head())
# Out:
# <bound method DataFrame.count of      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 0             R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1             R   2h 55m                         An offer you can't refuse.
# 2         PG-13   2h 32m                                    Why So Serious?
# 3             R   3h 22m       All the power on earth can't change destiny.
# 4      Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
# ..          ...      ...                                                ...
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 0         25000000       28884504
# 1          6000000      250341816
# 2        185000000     1006234167
# 3         13000000       47961919
# 4           350000            955
# ..             ...            ...
# 245       25000000      216639112
# 246        4000000          14480
# 247  Not Available  Not Available
# 248       22000000       52767889
# 249       22000000      424208848
#
#                                                  casts  \
# 0    Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1    Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 2    Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 3    Al Pacino,Robert De Niro,Robert Duvall,Diane K...
# 4    Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...
# ..                                                 ...
# 245  Viola Davis,Emma Stone,Octavia Spencer,Bryce D...
# 246  Maksim Munzuk,Yuriy Solomin,Mikhail Bychkov,Vl...
# 247  Scott Weinger,Robin Williams,Linda Larkin,Jona...
# 248  Ben Kingsley,John Gielgud,Rohini Hattangadi,Ro...
# 249  Kevin Costner,Mary McDonnell,Graham Greene,Rod...
#
#                     directors                                          writers
# 0              Frank Darabont                      Stephen King,Frank Darabont
# 1        Francis Ford Coppola                  Mario Puzo,Francis Ford Coppola
# 2           Christopher Nolan  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3        Francis Ford Coppola                  Francis Ford Coppola,Mario Puzo
# 4                Sidney Lumet                                    Reginald Rose
# ..                        ...                                              ...
# 245               Tate Taylor                     Tate Taylor,Kathryn Stockett
# 246            Akira Kurosawa    Akira Kurosawa,Yuriy Nagibin,Vladimir Arsenev
# 247  Ron Clements,John Musker             Ron Clements,John Musker,Ted Elliott
# 248      Richard Attenborough                                      John Briley
# 249             Kevin Costner                                    Michael Blake
#
# [250 rows x 13 columns]>
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office  ...          casts_11      casts_12        casts_13  \
# 0   25000000    28884504  ...       Brian Libby  David Proval    Joseph Ragno
# 1    6000000   250341816  ...       Talia Shire  Gianni Russo     John Cazale
# 2  185000000  1006234167  ...  Nestor Carbonell  Eric Roberts  Ritchie Coster
# 3   13000000    47961919  ...        Tom Rosqui   Bruno Kirby    Frank Sivero
# 4     350000         955  ...     Robert Webber     Rudy Bond      Tom Gorman
#
#                casts_14          casts_15         casts_16          casts_17  \
# 0       Jude Ciccolella      Paul McCrane     Renee Blaine        Scott Mann
# 1             Rudy Bond        Al Martino     Morgana King     Lenny Montana
# 2  Anthony Michael Hall  Keith Szarabajka  Colin McFarlane      Joshua Harto
# 3    Francesca De Sapio      Morgana King    Marianna Hill  Leopoldo Trieste
# 4           James Kelly      Billy Nelson      John Savoca    Walter Stocker
#
#             directors_0 directors_1 directors_2
# 0        Frank Darabont        None        None
# 1  Francis Ford Coppola        None        None
# 2     Christopher Nolan        None        None
# 3  Francis Ford Coppola        None        None
# 4          Sidney Lumet        None        None
#
# [5 rows x 40 columns]

# %%
# prompt: can you give me a small uni variable analisis for df_with_array

box_office =pd.to_numeric( df_with_arrays['box_office'],errors="coerce", downcast=None)
budget =pd.to_numeric( df_with_arrays['budget'],errors="coerce", downcast=None)

# Get descriptive statistics for numerical columns
df_with_arrays.describe()

# Get the unique values for categorical columns
for col in df_with_arrays.select_dtypes(include='object'):
  print(f"Unique values for '{col}':")
  print(df_with_arrays[col].unique())

# Get the frequency distribution for categorical columns
for col in df_with_arrays.select_dtypes(include='object'):
  print(f"Frequency distribution for '{col}':")
  print(df_with_arrays[col].value_counts())


# Visualize the distribution of numerical columns using histograms
import matplotlib.pyplot as plt
for col in df_with_arrays.select_dtypes(include='number'):
  plt.hist(df_with_arrays[col])
  plt.xlabel(col)
  plt.ylabel("Count")
  plt.title(f"Distribution of '{col}'")
  plt.show()

#box office
plt.hist(box_office)
plt.xlabel("Box office")
plt.ylabel("Count")
plt.title(f"Distribution of box office")
plt.show()

#budget
plt.hist(budget)
plt.xlabel("Budget")
plt.ylabel("Count")
plt.title(f"Distribution of 'budget'")
plt.show()

df_with_arrays['year'].value_counts().sort_index().plot.area()
plt.xlabel("Year")
plt.ylabel("Count")
plt.title(f"Distribution of Year")
plt.show()

df_with_arrays['rating'].value_counts().sort_index().plot.area()
plt.xlabel("ratings")
plt.ylabel("Count")
plt.title(f"Distribution of ratings")
plt.show()

df_with_arrays['certificate'].value_counts().sort_index().plot.bar()
plt.xlabel("Certificate")
plt.ylabel("Count")
plt.title(f"Distribution of Certificate")
plt.show()
# Out:
# Unique values for 'name':
# ['The Shawshank Redemption' 'The Godfather' 'The Dark Knight'
#  'The Godfather Part II' '12 Angry Men' "Schindler's List"
#  'The Lord of the Rings: The Return of the King' 'Pulp Fiction'
#  'The Lord of the Rings: The Fellowship of the Ring'
#  'The Good, the Bad and the Ugly' 'Forrest Gump' 'Fight Club'
#  'The Lord of the Rings: The Two Towers' 'Inception'
#  'Star Wars: Episode V - The Empire Strikes Back' 'The Matrix'
#  'Goodfellas' "One Flew Over the Cuckoo's Nest" 'Se7en' 'Seven Samurai'
#  "It's a Wonderful Life" 'The Silence of the Lambs' 'City of God'
#  'Saving Private Ryan' 'Interstellar' 'Life Is Beautiful' 'The Green Mile'
#  'Star Wars: Episode IV - A New Hope' 'Terminator 2: Judgment Day'
#  'Back to the Future' 'Spirited Away' 'The Pianist' 'Psycho' 'Parasite'
#  'Léon: The Professional' 'The Lion King' 'Gladiator' 'American History X'
#  'The Departed' 'The Usual Suspects' 'The Prestige' 'Whiplash'
#  'Casablanca' 'Grave of the Fireflies' 'Harakiri' 'The Intouchables'
#  'Modern Times' 'Once Upon a Time in the West' 'Rear Window'
#  'Cinema Paradiso' 'Alien' 'City Lights' 'Apocalypse Now' 'Memento'
#  'Django Unchained' 'Indiana Jones and the Raiders of the Lost Ark'
#  'WALL·E' 'The Lives of Others' 'Sunset Blvd.' 'Paths of Glory'
#  'The Shining' 'The Great Dictator' 'Avengers: Infinity War'
#  'Witness for the Prosecution' 'Aliens'
#  'Spider-Man: Into the Spider-Verse' 'American Beauty'
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'
#  'The Dark Knight Rises' 'Oldboy' 'Inglourious Basterds' 'Amadeus' 'Coco'
#  'Toy Story' 'Joker' 'Braveheart' 'The Boat' 'Avengers: Endgame'
#  'Princess Mononoke' 'Once Upon a Time in America' 'Good Will Hunting'
#  'Your Name.' '3 Idiots' "Singin' in the Rain" 'Requiem for a Dream'
#  'Toy Story 3' 'High and Low' 'Capernaum'
#  'Star Wars: Episode VI - Return of the Jedi'
#  'Eternal Sunshine of the Spotless Mind' '2001: A Space Odyssey'
#  'Reservoir Dogs' 'Come and See' 'The Hunt' 'Citizen Kane' 'M'
#  'Lawrence of Arabia' 'North by Northwest' 'Vertigo' 'Ikiru' 'Amélie'
#  'The Apartment' 'A Clockwork Orange' 'Double Indemnity'
#  'Full Metal Jacket' 'Top Gun: Maverick' 'Scarface' 'Hamilton' 'Incendies'
#  'To Kill a Mockingbird' 'Heat' 'The Sting' 'Up' 'A Separation'
#  'Metropolis' 'Taxi Driver' 'L.A. Confidential' 'Die Hard' 'Snatch'
#  'Indiana Jones and the Last Crusade' 'Bicycle Thieves'
#  'Like Stars on Earth' '1917' 'Downfall' 'Dangal' 'For a Few Dollars More'
#  'Batman Begins' 'The Kid' 'Some Like It Hot' 'The Father' 'All About Eve'
#  'The Wolf of Wall Street' 'Green Book' 'Judgment at Nuremberg' 'Casino'
#  'Ran' "Pan's Labyrinth" 'The Truman Show' 'There Will Be Blood'
#  'Unforgiven' 'The Sixth Sense' 'Shutter Island' 'A Beautiful Mind'
#  'Jurassic Park' 'Yojimbo' 'The Treasure of the Sierra Madre'
#  'Monty Python and the Holy Grail' 'The Great Escape'
#  'No Country for Old Men' 'Spider-Man: No Way Home' 'Kill Bill: Vol. 1'
#  'Rashomon' 'The Thing' 'Finding Nemo' 'The Elephant Man' 'Chinatown'
#  'Raging Bull' 'V for Vendetta' 'Gone with the Wind'
#  'Lock, Stock and Two Smoking Barrels' 'Inside Out' 'Dial M for Murder'
#  'The Secret in Their Eyes' "Howl's Moving Castle"
#  'Three Billboards Outside Ebbing, Missouri'
#  'The Bridge on the River Kwai' 'Trainspotting' 'Prisoners' 'Warrior'
#  'Fargo' 'Gran Torino' 'My Neighbor Totoro' 'Catch Me If You Can'
#  'Million Dollar Baby' 'Children of Heaven' 'Blade Runner' 'The Gold Rush'
#  'Before Sunrise' '12 Years a Slave' 'Klaus'
#  'Harry Potter and the Deathly Hallows: Part 2' 'On the Waterfront'
#  'Ben-Hur' 'Gone Girl' 'The Grand Budapest Hotel' 'Wild Strawberries'
#  'The General' 'The Third Man' 'In the Name of the Father'
#  'The Deer Hunter' 'Barry Lyndon' 'Hacksaw Ridge' 'The Wages of Fear'
#  'Memories of Murder' 'Sherlock Jr.' 'Wild Tales'
#  'Mr. Smith Goes to Washington' 'Mad Max: Fury Road' 'The Seventh Seal'
#  'Mary and Max' 'How to Train Your Dragon' 'Room' 'Monsters, Inc.' 'Jaws'
#  'Dead Poets Society' 'The Big Lebowski' 'Tokyo Story'
#  'The Passion of Joan of Arc' 'Hotel Rwanda' 'Ford v Ferrari' 'Rocky'
#  'Platoon' 'Ratatouille' 'Spotlight' 'The Terminator' 'Logan'
#  'Stand by Me' 'Rush' 'Network' 'Into the Wild' 'Before Sunset'
#  'The Wizard of Oz' 'Pather Panchali' 'Groundhog Day'
#  'The Best Years of Our Lives' 'The Exorcist' 'The Incredibles'
#  'To Be or Not to Be' 'La haine' 'The Battle of Algiers'
#  'Pirates of the Caribbean: The Curse of the Black Pearl'
#  "Hachi: A Dog's Tale" 'The Grapes of Wrath' 'Jai Bhim'
#  'My Father and My Son' 'Amores Perros' 'Rebecca' 'Cool Hand Luke'
#  'The Handmaiden' 'The 400 Blows' 'The Sound of Music'
#  'It Happened One Night' 'Persona' 'Life of Brian' 'The Iron Giant'
#  'The Help' 'Dersu Uzala' 'Aladdin' 'Gandhi' 'Dances with Wolves']
# Unique values for 'genre':
# ['Drama' 'Crime,Drama' 'Action,Crime,Drama' 'Biography,Drama,History'
#  'Action,Adventure,Drama' 'Adventure,Western' 'Drama,Romance'
#  'Action,Adventure,Sci-Fi' 'Action,Adventure,Fantasy' 'Action,Sci-Fi'
#  'Biography,Crime,Drama' 'Crime,Drama,Mystery' 'Action,Drama'
#  'Drama,Family,Fantasy' 'Crime,Drama,Thriller' 'Drama,War'
#  'Adventure,Drama,Sci-Fi' 'Comedy,Drama,Romance' 'Crime,Drama,Fantasy'
#  'Adventure,Comedy,Sci-Fi' 'Animation,Adventure,Family'
#  'Biography,Drama,Music' 'Horror,Mystery,Thriller' 'Drama,Thriller'
#  'Animation,Adventure,Drama' 'Drama,Mystery,Sci-Fi' 'Drama,Music'
#  'Drama,Romance,War' 'Animation,Drama,War' 'Action,Drama,Mystery'
#  'Biography,Comedy,Drama' 'Western' 'Mystery,Thriller' 'Horror,Sci-Fi'
#  'Drama,Mystery,War' 'Drama,Western' 'Action,Adventure'
#  'Drama,Mystery,Thriller' 'Drama,Film-Noir' 'Drama,Horror'
#  'Comedy,Drama,War' 'Animation,Action,Adventure' 'Comedy,War'
#  'Adventure,Drama,War' 'Animation,Adventure,Comedy'
#  'Animation,Drama,Fantasy' 'Comedy,Drama' 'Comedy,Musical,Romance'
#  'Drama,Romance,Sci-Fi' 'Adventure,Sci-Fi' 'Crime,Thriller'
#  'Drama,Thriller,War' 'Drama,Mystery' 'Crime,Mystery,Thriller'
#  'Adventure,Biography,Drama' 'Action,Adventure,Mystery'
#  'Mystery,Romance,Thriller' 'Comedy,Romance' 'Crime,Sci-Fi'
#  'Crime,Drama,Film-Noir' 'Comedy,Crime,Drama' 'Drama,Sci-Fi'
#  'Action,Thriller' 'Comedy,Crime' 'Drama,Family' 'Action,Drama,War'
#  'Action,Biography,Drama' 'Comedy,Drama,Family' 'Comedy,Music,Romance'
#  'Biography,Comedy,Crime' 'Drama,Fantasy,War' 'Biography,Drama'
#  'Action,Drama,Thriller' 'Adventure,Drama,Western'
#  'Adventure,Comedy,Fantasy' 'Adventure,Drama,History'
#  'Horror,Mystery,Sci-Fi' 'Biography,Drama,Sport' 'Action,Drama,Sci-Fi'
#  'Action,Comedy,Crime' 'Drama,Mystery,Romance' 'Action,Drama,Sport'
#  'Animation,Comedy,Family' 'Drama,Sport' 'Drama,Family,Sport'
#  'Adventure,Comedy,Drama' 'Adventure,Family,Fantasy' 'Adventure,Drama'
#  'Adventure,Comedy,Crime' 'Action,Adventure,Comedy'
#  'Film-Noir,Mystery,Thriller' 'Adventure,Drama,Thriller'
#  'Action,Comedy,Romance' 'Comedy,Drama,Thriller' 'Drama,Fantasy'
#  'Animation,Comedy,Drama' 'Adventure,Thriller' 'Comedy,Drama,Fantasy'
#  'Horror' 'Comedy,Romance,War' 'Biography,Drama,Family'
#  'Drama,Film-Noir,Mystery' 'Drama,Romance,Thriller' 'Comedy']
# Unique values for 'certificate':
# ['R' 'PG-13' 'Approved' 'PG' '18+' 'Not Rated' 'G' 'Passed'
#  'Not Available' 'TV-PG' 'Unrated' 'X' '13+' 'TV-MA' 'GP']
# Unique values for 'run_time':
# ['2h 22m' '2h 55m' '2h 32m' '3h 22m' '1h 36m' '3h 15m' '3h 21m' '2h 34m'
#  '2h 58m' '2h 19m' '2h 59m' '2h 28m' '2h 4m' '2h 16m' '2h 25m' '2h 13m'
#  '2h 7m' '3h 27m' '2h 10m' '1h 58m' '2h 49m' '1h 56m' '3h 9m' '2h 1m'
#  '2h 17m' '2h 5m' '2h 30m' '1h 49m' '2h 12m' '1h 50m' '1h 28m' '2h 35m'
#  '1h 59m' '2h 31m' '1h 46m' '1h 42m' '1h 29m' '1h 52m' '1h 27m' '2h 45m'
#  '1h 57m' '2h 27m' '1h 53m' '1h 55m' '1h 38m' '2h 26m' '2h 29m' '2h 2m'
#  '1h 35m' '2h 44m' '2h' '2h 33m' '2h 40m' '1h 45m' '1h 21m'
#  'Not Available' '3h 1m' '2h 14m' '3h 49m' '2h 6m' '2h 50m' '1h 43m'
#  '2h 23m' '2h 11m' '1h 48m' '1h 39m' '3h 38m' '2h 8m' '1h 47m' '2h 9m'
#  '2h 3m' '1h 54m' '2h 18m' '2h 36m' '2h 41m' '2h 20m' '1h 8m' '1h 37m'
#  '3h' '2h 42m' '2h 38m' '2h 15m' '1h 31m' '2h 52m' '1h 51m' '1h 40m'
#  '3h 58m' '1h 33m' '1h 26m' '2h 21m' '1h 41m' '3h 32m' '1h 7m' '3h 3m'
#  '3h 5m' '45m' '1h 32m' '1h 20m' '1h 23m' '1h 34m' '1h 30m' '3h 11m']
# Unique values for 'tagline':
# ['Fear can hold you prisoner. Hope can set you free.'
#  "An offer you can't refuse." 'Why So Serious?'
#  "All the power on earth can't change destiny."
#  'Life Is In Their Hands -- Death Is On Their Minds!'
#  'Whoever saves one life, saves the world entire.'
#  'The eye of the enemy is moving.'
#  "Girls like me don't make invitations like this to just anyone!"
#  'The Legend Comes to Life'
#  "They formed an alliance of hate to steal a fortune in dead man's gold"
#  'The story of a lifetime.'
#  "How much can you know about yourself if you've never been in a fight?"
#  'A New Power Is Rising.' 'Your mind is the scene of the crime'
#  'The Adventure Continues...' 'Free your mind'
#  '"As far back as I can remember, I\'ve always wanted to be a gangster." -- Henry Hill, Brooklyn, N.Y. 1955.'
#  "If he's crazy, what does that make you?"
#  'Long is the way, and hard, that out of hell leads up to light.'
#  'Will Take Its Place With the Seven Greatest Films of All Time!'
#  'Frank Capra\'s..."It\'s a Wonderful Life".'
#  'Dr. Hannibal Lecter. Brilliant. Cunning. Psychotic. In his mind lies the clue to a ruthless killer. - Clarice Starling, FBI. Brilliant. Vulnerable. Alone. She must trust him to stop the killer.'
#  'If you run, the beast will get you. If you stay, the beast will eat you'
#  'In the Last Great Invasion of the Last Great War, The Greatest Danger for Eight Men was Saving... One.'
#  'Mankind was born on Earth. It was never meant to die here.'
#  'An unforgettable fable that proves love, family and imagination conquer all. (Canadian one sheet)'
#  'Miracles do happen.'
#  "It's Back! The Force will be with you for three weeks only. (1979 Reissue Poster)"
#  "It's nothing personal."
#  "He's the only kid ever to get into trouble before he was born. [UK]"
#  'The tunnel led Chihiro to a mysterious town.'
#  'Music was his passion. Survival was his masterpiece.'
#  "The picture you MUST see from the beginning... Or not at all!... For no one will be seated after the start of... Alfred Hitchcock's greatest shocker Psycho."
#  'Misplaced familyhood (Australia/New Zealand/Singapore)'
#  'If you want the job done right, hire a professional.'
#  'See it for the first time ever in 3D (2011 3D re-release)'
#  'Father of a murdered son, husband to a murdered wife and I shall have my vengeance in this life or the next'
#  'His father taught him to hate. His friends taught him rage. His enemies gave him hope.'
#  'Lies. Betrayal. Sacrifice. How far will you take it?'
#  "The greatest trick the devil ever pulled was to convince the world he didn't exist"
#  'A Friendship That Became a Rivalry.'
#  'The road to greatness can take you to the edge'
#  'Where Love Cuts as Deep as a Dagger!' 'imationDramaWar'
#  'The World Has Never Understood Why the Japanese Prefer Death to Dishonor! This Samurai Picture Provides The Answer!!'
#  "Sometimes you have to reach into someone else's world to find out what's missing in your own."
#  'He stands alone as the greatest entertainer of modern times! No one on earth can make you laugh as heartily or touch your heart as deeply...the whole world laughs, cries and thrills to his priceless genius!'
#  'There were three men in her life. One knew her past. One wanted her land. One wanted revenge.'
#  'The Essential Hitchcock'
#  'A celebration of youth, friendship, and the everlasting magic of the movies.'
#  'In space no one can hear you scream.'
#  'HE RETURNS -And the world rocks again with laughter. (Print Ad-Daily Examiner, ((Grafton, NSW)) 6 July 1931)'
#  'The Horror. . . The Horror. . .' 'Some memories are best forgotten'
#  'Life, liberty and the pursuit of vengeance.'
#  'Indiana Jones - the new hero from the creators of JAWS and STAR WARS.'
#  "After 700 years of doing what he was built for - he'll discover what he's meant for."
#  "Before the Fall of the Berlin Wall, East Germany's Secret Police Listened to Your Secrets"
#  'A Hollywood Story'
#  'Never has the screen thrust so deeply into the guts of war!'
#  'Iconic terror from the No 1 bestselling writer.'
#  'The Comedy Masterpiece!' 'An entire universe. Once and for all.'
#  'The most electrifying entertainment of our time!'
#  "This time there's more."
#  'Enter a universe where more than one wears the mask.' '... look closer'
#  'The comedy classic from celebrated director STANLEY KUBRICK'
#  'The Legend Ends' '15 years of imprisonment, five days of vengeance'
#  'Once upon a time in Nazi occupied France...'
#  'The man... The music... The madness... The murder... The motion picture...'
#  'The celebration of a lifetime' '"Oooh...3-D" (USA 2009 re-release)'
#  'Put on a happy face.'
#  'The story of a man with a free soul...and with the courage to follow it.'
#  "This is the story of 42 raw recruits caught up in a war they didn't understand, and the Captain who must lead them in their struggle to survive."
#  'Avenge the fallen.' 'Live on.'
#  "Crime, passion and lust for power - Sergio Leone's explosive saga of gangland America."
#  'Some people can never believe in themselves, until someone believes in them.'
#  "Experience Japan's #1 film of 2016, from visionary director Makoto Shinkai"
#  "Don't be Stupid. Be an I.D.I.O.T."
#  "Singin' Swingin' Glorious Feelin' Technicolor Musical"
#  'From the director of [Pi]' 'The Breakout Comedy Of The Summer'
#  '142 Screenful Minutes of Thrills and Suspense!'
#  '"Why are you suing your parents?" "For giving me life."'
#  'Coming May 25, 1983 to your galaxy. [Second Advance poster]'
#  'I already forget how I used to feel about you.'
#  'Let the Awe and Mystery of a Journey Unlike Any Other Begin'
#  "Seven Total Strangers Team Up For The Perfect Crime. They Don't Know Each Other's Name. But They've Got Each Other's Color"
#  'The cruelest side of war.' 'The lie is spreading.'
#  "Radio's Most Dynamic Artist . . The Man At Whose Voice A Nation Trembled . . . Now the screen's most exciting NEW star ! ORSON WELLES in the picture Hollywood said he'd never make"
#  'IT STAGGERS THE SENSES!...SHOCKS the Imagination - It will leave you Gasping - It is the Sensation of 3 Continents!'
#  'A Mighty Motion Picture Of Action And Adventure!'
#  'Alfred Hitchcock takes you.... North by Northwest!'
#  'A Hitchcock thriller. You should see it from the beginning!'
#  'One of the Great Films of Our Time!'
#  'One person can change your life forever.'
#  'Movie-wise, there has never been anything like "THE APARTMENT" love-wise, laugh-wise or otherwise-wise!'
#  "Being the adventures of a young man ... who couldn't resist pretty girls ... or a bit of the old ultra-violence ... went to jail, was re-conditioned ... and came out a different young man ... or was he ?"
#  "IT'S LOVE AND MURDER AT FIRST SIGHT! (print ad - Lubbock Morning Avalanche - Lindsey Theatre - Lubbock, Texas - September 1, 1944 - all caps)"
#  'An Epic Story of the Vietnam War [Australia Theatrical]'
#  'Feel the need... The need for speed.'
#  'He was Tony Montana. The world will remember him by another name...SCARFACE.'
#  'An American Musical'
#  "The search began at the opening of their mother's will."
#  'The most beloved and widely read Pulitzer Prize Winner now comes vividly alive on the screen!'
#  'An L.A. Redemption'
#  'Recapture "the STING Experience". REMEMBER HOW GOOD THE FEEL WAS THE FIRST TIME (re-release)'
#  'Fly Up to Venezuela' 'Ugly truth, sweet lies'
#  "Fritz Lang's 1927 Masterpiece Now With 25 Minutes of Lost Footage (2010 re-release)"
#  "On every street in every city in this country, there's a nobody who dreams of being a somebody."
#  'Off the record, on the QT, and very hush-hush...'
#  'It will blow you through the back wall of the theater!'
#  "Stealin' Stones and Breakin' Bones"
#  "He's back in an all new adventure. Memorial Day 1989."
#  'The Prize Picture They Want to Censor!' 'Every Child is Special'
#  'Time is the enemy.' 'April 1945, a nation awaits its...'
#  'You think our girls are any lesser than boys?'
#  'The man with no name is back.' 'The Legend Begins'
#  'This is the great film he has been working on for a whole year'
#  'Not since SCARFACE, so much action. Not since the Marx Brothers, so much comedy. Not since THE SEVEN YEAR ITCH, so much Marilyn.'
#  'Nothing is as it seems' "It's all about women---and their men!"
#  'Earn. Spend. Party.' 'Inspired by a True Friendship'
#  'More than a motion picture...It is an overwhelming experience in human emotion you will never forget!'
#  "You don't stay at the top forever" 'tionDramaWar'
#  "What happens when make-believe believes it's real?"
#  "All the world's a stage..."
#  'There Will Be Greed. There Will Be Vengeance.'
#  "It's a hell of a thing, killing a man" '"I see dead people"'
#  'Someone is missing.'
#  'The Only Thing Greater Than the Power of the Mind is the Courage of the Heart'
#  'Life finds a way.' 'Better if all these men were dead. Think about it!'
#  'Storming to a New High in High Adventure !'
#  'You can do worse than see it.'
#  "put a fence in front of these men...and they'll climb it..."
#  'There Are No Clean Getaways' 'The Multiverse Unleashed.'
#  'In the year 2003, Uma Thurman will kill Bill'
#  'The husband, the wife...or the bandit?' 'Anytime. Anywhere. Anyone.'
#  "71% of the Earth's surface is covered by water. That's a lot of space to find one fish."
#  "An incredible but true story... probably this year's best film."
#  'You get tough. You get tender. You get close to each other. Maybe you even get close to the truth.'
#  'ographyDramaSport'
#  'Remember, remember the 5th of November, the gun powder treason and plot. I know of no reason why the gun powder treason should ever be forgot.'
#  "For the thousands who remember its unparalleled drama, action and romance! For the new thousands to whom the wonders will be revealed for the first time! Breathtaking spectacle, inspired acting by the greatest cast ever assembled! The screen's most exciting love story! The most-talked about picture ever made! [reissue]"
#  'A Disgrace to Criminals Everywhere.'
#  'Meet the little voices inside your head.'
#  'Kiss By Kiss...Supreme Suspense Unfurls!'
#  'Un crimen sin castigo. Un amor puro. Una historia que no debe morir. [A crime without a punishment. A pure love. A story that must not die.]'
#  'imationAdventureFamilyFantasy' 'medyCrimeDrama'
#  'The towering triumph of adventure from the makers of "Lawrence of Arabia."'
#  'Choose life. Choose a job. Choose a starter home. Choose dental insurance, leisure wear and matching luggage. Choose your future. But why would anyone want to do a thing like that?'
#  'Every moment matters' 'Fight for Country' 'A homespun murder story.'
#  'ma' 'imationComedyFamilyFantasy' 'The true story of a real fake.'
#  'Beyond his silence, there is a past. Beyond her dreams, there is a feeling. Beyond hope, there is a memory. Beyond their journey, there is a love.'
#  'A Little Secret...Their Biggest Adventure!'
#  'A Futuristic Vision Perfected [2007 Final Cut]'
#  '"The Picture I Want to Be Remembered by." -Charlie Chaplin. (Print Ad- Calgary Daily Herald, ((Calgary, Alta.)) 30 December 1925)'
#  'Jump on and live a Eurorail journey you will never forget!'
#  'The extraordinary true story of Solomon Northup'
#  'Discover the friendship that launched a legend.' 'It All Ends Here'
#  'The Man Lived by the Jungle Law of the Docks!' 'A Tale of the Christ'
#  "You don't know what you've got 'til it's..." 'ventureComedyCrime'
#  '"We are such stuff as dreams are made on, and our little life is rounded with a sleep." Shakespeare - The Tempest'
#  'Buster drives "The General" to trainload of laughter. (Trade paper ad).'
#  "Carol Reed's Classic Thriller"
#  "Falsely accused.  Wrongly imprisoned.  He fought for justice to clear his father's name."
#  'One of the most important and powerful films of all time!'
#  'At long last Redmond Barry became a gentleman -- and that was his tragedy.'
#  'Based on the incredible true story.'
#  'The complete restored version of the 1953 French classic [reissue]'
#  '1986 in a small town...for two detectives, everything was new.'
#  'every inch of footage holds such a laugh!' 'We can all lose control'
#  'OUR OPERATOR SAYS.."IT\'S GOING TO BE A PLEASURE TO RUN "MR. SMITH GOES TO WASHINGTON" 5 DAYS STARTING SUNDAY, NOV.7) (print ad - Lubbock Morning Avalanche - Cactus Theatre - Lubbock Texas - November 2, 1938 - all caps)'
#  'WHAT A LOVELY DAY (all caps One Sheet)'
#  'A film of visual scope, of imaginative concept, of powerful content, written and directed by Ingmar Bergman, twice honored by the Interational Jury at the Cannes Film Festival 1956,1957'
#  'Two unlikely people. Two different worlds come together in a story about a most unusual friendship.'
#  'One adventure will change two worlds' 'Love knows no boundaries'
#  'Monsters, Inc. : We Scare Because We Care'
#  'Amity Island had everything. Clear skies. Gentle surf. Warm water. People flocked there every summer. It was the perfect feeding ground.'
#  'He was their inspiration. He made their lives extraordinary.'
#  'Hay quienes tratan de ganarse la vida sin mover un dedo... otros tienen que cortarlos. (Mexico)'
#  'As long as life goes on, relationships between parents and children will bring boundless joy and endless grief.'
#  'JOAN of ARC PICTURES Inc. presents'
#  'When a country descended into madness and the world turned its back, one man had to make a choice'
#  'They took the American dream for a ride.'
#  'You have a ringside seat for the bloodiest bicentennial in history!'
#  'The first casualty of war is innocence.'
#  'Dinner is served... Summer 2007' 'Break the story. Break the silence.'
#  'La sua missione e una sola: distruggere, uccidere... (His one and only mission: to destroy, to kill...) (Italian DVD)'
#  'His time has come'
#  "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of."
#  "Everyone's driven by something."
#  '"NETWORK"... the humanoids, the love story, the trials and tribulations, the savior of television, the attempted suicides, the assassination -- it\'s ALL coming along with a galaxy of stars you know and love!'
#  'Into the heart Into the soul'
#  'What if you had a second chance with the one that got away?'
#  'Mighty Miracle Show Of 1000 Delights !' 'The Saga of an Indian Family'
#  'What would you do if you were stuck in the same day... over and over? Anything you want and everything your heart desires.'
#  "THE SCREEN'S GREATEST LOVE STORY IS THE BEST FILM THIS YEAR FROM HOLLYWOOD!"
#  "The movie you've been waiting for...without the wait." 'Save The Day'
#  'The Picture Everyone Wants To See.' 'So far, so good'
#  'The French Colonel...who was forced even to torture! One of the many women...who stopped at nothing to win! The Algerian Street Boy...who became a rebel hero!'
#  'Prepare to be blown out of the water.'
#  'A true story of faith, devotion and undying love.'
#  'The thousands who have read the book will know why WE WILL NOT SELL ANY CHILDREN TICKETS to see this picture!'
#  'imeDramaMystery' 'Give him a room dad, he has no place to go...'
#  'Love. Betrayal. Death.'
#  'THE MIGHTY NOVEL LEAPS TO TURBULENT LIFE ON THE SCREEN! (Print Ad- Syracuse Herald-American, ((Syracuse, NY)) 24 March 1940)'
#  '"What we\'ve got here is failure to communicate."'
#  'Never did they expect to get into a controversial relationship...'
#  'From the Vanguard of New Film-Makers Comes an Extraordinary Motion Picture'
#  'RADIANCE THAT FLOODS THE SCREEN...AND WARMS THE HEART!'
#  'Two great lovers of the screen in the grandest of romantic comedies !'
#  'A new film by Ingmar Bergman'
#  'A motion picture destined to offend nearly two thirds of the civilized world. And severely annoy the other third.'
#  'Some secrets are too huge to hide' 'Change begins with a whisper.'
#  "There is man and beast at nature's mercy. There is awe and love and reverence. And there is the man called..."
#  'Wish granted! (DVD re-release)' 'His Triumph Changed The World Forever.'
#  'Inside everyone is a frontier waiting to be discovered.']
# Unique values for 'budget':
# ['25000000' '6000000' '185000000' '13000000' '350000' '22000000'
#  '94000000' '8000000' '93000000' '1200000' '55000000' '63000000'
#  '160000000' '18000000' '3000000' '33000000' '125000000' '3180000'
#  '19000000' '$3300000' '70000000' '165000000' '20000000' '60000000'
#  '11000000' '102000000' '35000000' '806947' '11400000' 'RF\xa0115000000'
#  '45000000' '103000000' '90000000' '40000000' '3300000' '950000' '3700000'
#  'Not Available' '9500000' '1500000' '5000000' '1000000' '31500000'
#  '9000000' '100000000' '180000000' '2000000' '1752000' '935000'
#  '321000000' '18500000' '15000000' '1800000' '250000000' '175000000'
#  '30000000' '72000000' 'EM\xa032000000' '356000000' '2400000000'
#  '550000000' '2540800' '4500000' '200000000' '32500000' '12000000'
#  '839727' '3101000' '2479000' '10000000' '2200000' '927262' '170000000'
#  '6800000' '5500000' '500000' 'EM\xa06000000' '1300000' '28000000'
#  '48000000' '133000' '95000000' '13500000' '600000' '150000000' '250000'
#  '2883848' '1400000' '23000000' '52000000' '11500000' '14400000'
#  '80000000' '58000000' '229575' '4000000' '54000000' '3977000' '960000'
#  '24000000' '46000000' '7000000' '923000' '2500000' '910000' '750000'
#  '2800000' '1900000' '150000' '$8240000' '115000000' '16400000' '17500000'
#  '97600000' '6400000' '97000000' '38000000' '3800000' '2777000' '14600000'
#  '2100000' '92000000' '800000' '140000000' '1288000' '3200000' '8200000'
#  '325000']
# Unique values for 'box_office':
# ['28884504' '250341816' '1006234167' '47961919' '955' '322161245'
#  '1146457748' '213928762' '898204420' '25253887' '678226465' '101209702'
#  '947944270' '836848102' '538375067' '467222728' '47036784' '109114817'
#  '327333559' '346258' '8574081' '272742922' '30680793' '482349603'
#  '773867216' '230098753' '286801374' '775398007' '520881154' '383336762'
#  '355822319' '120072577' '32052925' '262676096' '19569225' '968511805'
#  '503162313' '23875127' '291480452' '23341568' '109676311' '49396747'
#  '4626532' '516962' 'Not Available' '426588510' '463618' '5435024'
#  '37034579' '13019063' '106285522' '50419' '104880868' '40047078'
#  '426074373' '389925971' '521311890' '77356942' '300073' '5252' '47335804'
#  '970263' '2052415039' '7693' '131060248' '356296601' '9523464'
#  '1081169825' '15421226' '321457747' '52066791' '814337054' '394436586'
#  '1074458282' '213216216' '11487676' '2799439100' '170005875' '5473337'
#  '60262836' '2000288' '7390108' '1067316101' '475106177' '74036715'
#  '65889846' '2913644' '1645133' '35566' '45720631' '142319' '7798146'
#  '96302' '174122191' '18778738' '26960374' '14651' '46358827' '1488732821'
#  '65884703' '6788659' '599146' '187436818' '156000000' '735099102'
#  '22926076' '1349711' '28570902' '126216940' '141603197' '83557872'
#  '474171806' '436655' '21897373' '384479940' '92181574' '15000000'
#  '373672993' '41960' '195088' '24427162' '151052' '406878233' '321752656'
#  '12180' '116112375' '4164283' '83862032' '264118201' '76182388'
#  '159167799' '672806432' '294805697' '316791257' '1109802321' '46808'
#  '5014000' '1940906' '228178' '171627434' '1921847111' '180906076' '81379'
#  '19632715' '941637960' '26023860' '29225935' '23402427' '134686457'
#  '402382193' '3753929' '858848019' '31207' '237536126' '162861289'
#  '27200000' '16767475' '122126687' '23308615' '60611975' '269958228'
#  '216763646' '41722424' '29328' '5987386' '187733202' '1342359942'
#  '910000 (estimated)' '74437720' '173082189' '60418' '750000 (estimated)'
#  '1226507' '49074379' '199632' '180563636' '1098' '1166717' '144738'
#  '415261382' '311212' '1740429' '494879471' '35401758' '579707738'
#  '476512065' '235860116' '46969409' '33882243' '225508210' '117250402'
#  '138545632' '623726085' '98690254' '78371200' '619179950' '52287414'
#  '96983009' '23690757' '56675895' '25637669' '135342' '71108591'
#  '23661347' '441306145' '631607053' '962002' '654264015'
#  '800000 (estimated)' '20908467' '72275' '67' '127244' '159428329' '11477'
#  '20745728' '23335817' '216639112' '14480' '52767889' '424208848']
# Unique values for 'casts':
# ['Tim Robbins,Morgan Freeman,Bob Gunton,William Sadler,Clancy Brown,Gil Bellows,Mark Rolston,James Whitmore,Jeffrey DeMunn,Larry Brandenburg,Neil Giuntoli,Brian Libby,David Proval,Joseph Ragno,Jude Ciccolella,Paul McCrane,Renee Blaine,Scott Mann'
#  'Marlon Brando,Al Pacino,James Caan,Diane Keaton,Richard S. Castellano,Robert Duvall,Sterling Hayden,John Marley,Richard Conte,Al Lettieri,Abe Vigoda,Talia Shire,Gianni Russo,John Cazale,Rudy Bond,Al Martino,Morgana King,Lenny Montana'
#  'Christian Bale,Heath Ledger,Aaron Eckhart,Michael Caine,Maggie Gyllenhaal,Gary Oldman,Morgan Freeman,Monique Gabriela Curnen,Ron Dean,Cillian Murphy,Chin Han,Nestor Carbonell,Eric Roberts,Ritchie Coster,Anthony Michael Hall,Keith Szarabajka,Colin McFarlane,Joshua Harto'
#  'Al Pacino,Robert De Niro,Robert Duvall,Diane Keaton,John Cazale,Talia Shire,Lee Strasberg,Michael V. Gazzo,G.D. Spradlin,Richard Bright,Gastone Moschin,Tom Rosqui,Bruno Kirby,Frank Sivero,Francesca De Sapio,Morgana King,Marianna Hill,Leopoldo Trieste'
#  'Henry Fonda,Lee J. Cobb,Martin Balsam,John Fiedler,E.G. Marshall,Jack Klugman,Edward Binns,Jack Warden,Joseph Sweeney,Ed Begley,George Voskovec,Robert Webber,Rudy Bond,Tom Gorman,James Kelly,Billy Nelson,John Savoca,Walter Stocker'
#  'Liam Neeson,Ralph Fiennes,Ben Kingsley,Caroline Goodall,Jonathan Sagall,Embeth Davidtz,Malgorzata Gebel,Shmuel Levy,Mark Ivanir,Béatrice Macola,Andrzej Seweryn,Friedrich von Thun,Krzysztof Luft,Harry Nehring,Norbert Weisser,Adi Nitzan,Michael Schneider,Miri Fabian'
#  'Elijah Wood,Viggo Mortensen,Ian McKellen,Orlando Bloom,Noel Appleby,Ali Astin,Sean Astin,David Aston,John Bach,Sean Bean,Cate Blanchett,Billy Boyd,Sadwyn Brophy,Alistair Browning,Marton Csokas,Richard Edge,Jason Fitch,Bernard Hill'
#  'John Travolta,Uma Thurman,Samuel L. Jackson,Bruce Willis,Tim Roth,Amanda Plummer,Laura Lovelace,Phil LaMarr,Frank Whaley,Burr Steers,Ving Rhames,Paul Calderon,Bronagh Gallagher,Rosanna Arquette,Eric Stoltz,Jerome Patrick Hoban,Michael Gilden,Gary Shorelle'
#  'Elijah Wood,Ian McKellen,Orlando Bloom,Sean Bean,Alan Howard,Noel Appleby,Sean Astin,Sala Baker,Billy Boyd,Andy Serkis,Marton Csokas,Viggo Mortensen,Megan Edwards,Michael Elsworth,Cate Blanchett,Mark Ferguson,Ian Holm,Christopher Lee'
#  'Clint Eastwood,Eli Wallach,Lee Van Cleef,Aldo Giuffrè,Luigi Pistilli,Rada Rassimov,Enzo Petito,Claudio Scarchilli,John Bartha,Livio Lorenzon,Antonio Casale,Sandro Scarchilli,Benito Stefanelli,Angelo Novi,Antonio Casas,Aldo Sambrell,Al Mulock,Sergio Mendizábal'
#  'Tom Hanks,Robin Wright,Gary Sinise,Sally Field,Rebecca Williams,Michael Conner Humphreys,Harold G. Herthum,George Kelly,Bob Penny,John Randall,Sam Anderson,Margo Moorer,Ione M. Telech,Christine Seabrook,John Worsham,Peter Dobson,Siobhan Fallon Hogan,Alexander Zemeckis'
#  "Brad Pitt,Edward Norton,Meat Loaf,Zach Grenier,Richmond Arquette,David Andrews,George Maguire,Eugenie Bondurant,Christina Cabot,Helena Bonham Carter,Sydney 'Big Dawg' Colston,Rachel Singer,Christie Cronenweth,Tim DeZarn,Ezra Buzzington,Dierdre Downing-Jackson,Bob Stephenson,Charlie Dell"
#  'Elijah Wood,Ian McKellen,Viggo Mortensen,Orlando Bloom,Bruce Allpress,Sean Astin,John Bach,Sala Baker,Cate Blanchett,Billy Boyd,Jed Brophy,Sam Comery,Brad Dourif,Calum Gittins,Bernard Hill,Bruce Hopkins,Paris Howe Strewe,Christopher Lee'
#  'Leonardo DiCaprio,Joseph Gordon-Levitt,Elliot Page,Ken Watanabe,Tom Hardy,Dileep Rao,Cillian Murphy,Tom Berenger,Marion Cotillard,Pete Postlethwaite,Michael Caine,Lukas Haas,Tai-Li Lee,Claire Geare,Magnus Nolan,Taylor Geare,Johnathan Geare,Tohoru Masamune'
#  'Mark Hamill,Harrison Ford,Carrie Fisher,Billy Dee Williams,Anthony Daniels,David Prowse,Peter Mayhew,Kenny Baker,Frank Oz,Alec Guinness,Jeremy Bulloch,John Hollis,Jack Purvis,Des Webb,Clive Revill,Kenneth Colley,Julian Glover,Michael Sheard'
#  'Keanu Reeves,Laurence Fishburne,Carrie-Anne Moss,Hugo Weaving,Gloria Foster,Joe Pantoliano,Marcus Chong,Julian Arahanga,Matt Doran,Belinda McClory,Anthony Ray Parker,Paul Goddard,Robert Taylor,David Aston,Marc Aden Gray,Ada Nicodemou,Deni Gordon,Rowan Witt'
#  'Robert De Niro,Ray Liotta,Joe Pesci,Lorraine Bracco,Paul Sorvino,Frank Sivero,Tony Darrow,Mike Starr,Frank Vincent,Chuck Low,Frank DiLeo,Henny Youngman,Gina Mastrogiacomo,Catherine Scorsese,Charles Scorsese,Suzanne Shepherd,Debi Mazar,Margo Winkler'
#  'Jack Nicholson,Louise Fletcher,Michael Berryman,Peter Brocco,Dean R. Brooks,Alonzo Brown,Scatman Crothers,Mwako Cumbuka,Danny DeVito,William Duell,Josip Elic,Lan Fendors,Nathan George,Ken Kenny,Mel Lambert,Sydney Lassick,Kay Lee,Christopher Lloyd'
#  'Morgan Freeman,Brad Pitt,Kevin Spacey,Andrew Kevin Walker,Daniel Zacapa,Gwyneth Paltrow,John Cassini,Bob Mack,Peter Crombie,Reg E. Cathey,R. Lee Ermey,George Christy,Endre Hules,Hawthorne James,William Davidson,Bob Collins,Jimmy Dale Hartsell,Richard Roundtree'
#  'Toshirô Mifune,Takashi Shimura,Keiko Tsushima,Yukiko Shimazaki,Kamatari Fujiwara,Daisuke Katô,Isao Kimura,Minoru Chiaki,Seiji Miyaguchi,Yoshio Kosugi,Bokuzen Hidari,Yoshio Inaba,Yoshio Tsuchiya,Kokuten Kôdô,Eijirô Tôno,Kichijirô Ueda,Jun Tatara,Atsushi Watanabe'
#  'James Stewart,Donna Reed,Lionel Barrymore,Thomas Mitchell,Henry Travers,Beulah Bondi,Frank Faylen,Ward Bond,Gloria Grahame,H.B. Warner,Frank Albertson,Todd Karns,Samuel S. Hinds,Mary Treen,Virginia Patton,Charles Williams,Sarah Edwards,William Edmunds'
#  "Jodie Foster,Anthony Hopkins,Lawrence A. Bonney,Kasi Lemmons,Lawrence T. Wrentz,Scott Glenn,Anthony Heald,Frankie Faison,Don Brockett,Frank Seals Jr.,Stuart Rudin,Maria Skorobogatov,Jeffrie Lane,Leib Lensky,George 'Red' Schwartz,Jim Roche,Brooke Smith,Ted Levine"
#  'Alexandre Rodrigues,Leandro Firmino,Matheus Nachtergaele,Phellipe Haagensen,Douglas Silva,Jonathan Haagensen,Seu Jorge,Jefechander Suplino,Alice Braga,Emerson Gomes,Edson Oliveira,Michel Gomes,Roberta Rodrigues,Luis Otávio,Kiko Marques,Gustavo Engrácia,Darlan Cunha,Robson Rocha'
#  'Tom Hanks,Matt Damon,Tom Sizemore,Edward Burns,Barry Pepper,Adam Goldberg,Vin Diesel,Giovanni Ribisi,Jeremy Davies,Ted Danson,Paul Giamatti,Dennis Farina,Joerg Stadler,Max Martini,Dylan Bruno,Daniel Cerqueira,Demetri Goritsas,Ian Porter'
#  'Matthew McConaughey,Anne Hathaway,Jessica Chastain,Mackenzie Foy,Ellen Burstyn,John Lithgow,Timothée Chalamet,David Oyelowo,Collette Wolfe,Francis X. McCarthy,Bill Irwin,Andrew Borba,Wes Bentley,William Devane,Michael Caine,David Gyasi,Josh Stewart,Casey Affleck'
#  'Roberto Benigni,Nicoletta Braschi,Giorgio Cantarini,Giustino Durano,Sergio Bini Bustric,Marisa Paredes,Horst Buchholz,Lidia Alfonsi,Giuliana Lojodice,Amerigo Fontani,Pietro De Silva,Francesco Guzzo,Raffaella Lebboroni,Claudio Alfonsi,Gil Baroni,Massimo Bianchi,Jürgen Bohn,Verena Buratti'
#  'Tom Hanks,Michael Clarke Duncan,David Morse,Bonnie Hunt,James Cromwell,Michael Jeter,Graham Greene,Doug Hutchison,Sam Rockwell,Barry Pepper,Jeffrey DeMunn,Patricia Clarkson,Harry Dean Stanton,Dabbs Greer,Eve Brent,William Sadler,Mack Miles,Rai Tasco'
#  'Mark Hamill,Harrison Ford,Carrie Fisher,Alec Guinness,Peter Cushing,Anthony Daniels,Kenny Baker,Peter Mayhew,David Prowse,Phil Brown,Shelagh Fraser,Jack Purvis,Alex McCrindle,Eddie Byrne,Drewe Henley,Denis Lawson,Garrick Hagon,Jack Klaff'
#  'Arnold Schwarzenegger,Linda Hamilton,Edward Furlong,Robert Patrick,Earl Boen,Joe Morton,S. Epatha Merkerson,Castulo Guerra,Danny Cooksey,Jenette Goldstein,Xander Berkeley,Leslie Hamilton Gearren,Ken Gibbel,Robert Winley,Peter Schrum,Shane Wilder,Michael Edwards,Jared Lounsbery'
#  'Michael J. Fox,Christopher Lloyd,Lea Thompson,Crispin Glover,Tom Wilson,Claudia Wells,Marc McClure,Wendie Jo Sperber,George DiCenzo,Frances Lee McCain,James Tolkan,J.J. Cohen,Casey Siemaszko,Billy Zane,Harry Waters Jr.,Donald Fullilove,Lisa Freeman,Cristen Kauffman'
#  'Daveigh Chase,Suzanne Pleshette,Miyu Irino,Rumi Hiiragi,Mari Natsuki,Takashi Naitô,Yasuko Sawaguchi,Tatsuya Gashûin,Ryûnosuke Kamiki,Yumi Tamai,Yô Ôizumi,Koba Hayashi,Tsunehiko Kamijô,Takehiko Ono,Bunta Sugawara,Shigeru Wakita,Shirô Saitô,Michiko Yamamoto'
#  'Adrien Brody,Thomas Kretschmann,Frank Finlay,Emilia Fox,Michal Zebrowski,Ed Stoppard,Maureen Lipman,Jessica Kate Meyer,Julia Rayner,Wanja Mues,Richard Ridings,Nomi Sharron,Anthony Milner,Lucy Skeaping,Roddy Skeaping,Ben Harlan,Thomas Lawinky,Joachim Paul Assböck'
#  'Anthony Perkins,Janet Leigh,Vera Miles,John Gavin,Martin Balsam,John McIntire,Simon Oakland,Frank Albertson,Patricia Hitchcock,Vaughn Taylor,Lurene Tuttle,John Anderson,Mort Mills,Fletcher Allen,Walter Bacon,Prudence Beers,Kit Carson,Francis De Sales'
#  'Song Kang-ho,Lee Sun-kyun,Cho Yeo-jeong,Choi Woo-sik,Park So-dam,Lee Jeong-eun,Jang Hye-jin,Park Myeong-hoon,Jung Ji-so,Jung Hyun-jun,Park Keun-rok,Jung Yi-seo,Jo Jae-myeong,Jung Ik-han,Kim Kyu-baek,Hwang In-kyung,Ahn Seong-bong,Kim Jin-hyung'
#  'Jean Reno,Gary Oldman,Natalie Portman,Danny Aiello,Peter Appel,Willi One Blood,Don Creech,Keith A. Glascoe,Randolph Scott,Michael Badalucco,Ellen Greene,Elizabeth Regen,Carl J. Matusovich,Frank Senger,Lucius Wyatt Cherokee,Eric Challier,Luc Bernard,Maïwenn'
#  'Matthew Broderick,Jeremy Irons,James Earl Jones,Whoopi Goldberg,Rowan Atkinson,Niketa Calame-Harris,Jim Cummings,Robert Guillaume,Moira Kelly,Nathan Lane,Zoe Leader,Cheech Marin,Ernie Sabella,Madge Sinclair,Jonathan Taylor Thomas,Frank Welker,Cathy Cavadini,Judi M. Durand'
#  'Russell Crowe,Joaquin Phoenix,Connie Nielsen,Oliver Reed,Richard Harris,Derek Jacobi,Djimon Hounsou,David Schofield,John Shrapnel,Tomas Arana,Ralf Moeller,Spencer Treat Clark,David Hemmings,Tommy Flanagan,Sven-Ole Thorsen,Omid Djalili,Nicholas McGaughey,Chris Kell'
#  "Edward Norton,Edward Furlong,Beverly D'Angelo,Jennifer Lien,Ethan Suplee,Fairuza Balk,Avery Brooks,Elliott Gould,Stacy Keach,William Russ,Guy Torry,Joe Cortese,Jason Bose Smith,Antonio David Lyons,Alex Sol,Keram Malicki-Sánchez,Giuseppe Andrews,Michelle Christine White"
#  "Leonardo DiCaprio,Matt Damon,Jack Nicholson,Mark Wahlberg,Martin Sheen,Ray Winstone,Vera Farmiga,Anthony Anderson,Alec Baldwin,Kevin Corrigan,James Badge Dale,David O'Hara,Mark Rolston,Robert Wahlberg,Kristen Dalton,Thomas B. Duffy,Richard Hughes,J.C. MacKenzie"
#  'Kevin Spacey,Gabriel Byrne,Chazz Palminteri,Stephen Baldwin,Benicio Del Toro,Kevin Pollak,Pete Postlethwaite,Suzy Amis,Giancarlo Esposito,Dan Hedaya,Paul Bartel,Carl Bressler,Phillipe Simon,Jack Shearer,Christine Estabrook,Clark Gregg,Morgan Hunter,Ken Daly'
#  'Christian Bale,Hugh Jackman,Scarlett Johansson,Michael Caine,Piper Perabo,Rebecca Hall,Samantha Mahurin,David Bowie,Andy Serkis,Daniel Davis,Jim Piddock,Christopher Neame,Mark Ryan,Roger Rees,Jamie Harris,Monty Stuart,Ron Perkins,Ricky Jay'
#  'Miles Teller,J.K. Simmons,Melissa Benoist,Paul Reiser,Austin Stowell,Nate Lang,Chris Mulkey,Damon Gupton,Suanne Spoke,Max Kasch,Charlie Ian,Jayson Blair,Kofi Siriboe,Kavita Patil,C.J. Vana,Tarik Lowe,Tyler Kimball,Rogelio Douglas Jr.'
#  'Humphrey Bogart,Ingrid Bergman,Paul Henreid,Claude Rains,Conrad Veidt,Sydney Greenstreet,Peter Lorre,S.Z. Sakall,Madeleine Lebeau,Dooley Wilson,Joy Page,John Qualen,Leonid Kinskey,Curt Bois,Abdullah Abbas,Enrique Acosta,Ed Agresti,Arnet Amos'
#  'Tsutomu Tatsumi,Ayano Shiraishi,Akemi Yamaguchi,Yoshiko Shinohara,Kôzô Hashida,Masayo Sakai,Kazumi Nozaki,Yoshio Matsuoka,Masahiro Kanetake,Kiyoshi Yanagawa,Hajime Maki,Atsuo Omote,Teruhisa Harita,Hiroshi Tanaka,Michio Denpô,Shirô Tamaki,Tadashi Nakamura,Mika Sekita'
#  'Tatsuya Nakadai,Akira Ishihama,Shima Iwashita,Tetsurô Tanba,Masao Mishima,Ichirô Nakatani,Kei Satô,Yoshio Inaba,Hisashi Igawa,Tôru Takeuchi,Yoshirô Aoki,Tatsuo Matsumura,Akiji Kobayashi,Kôichi Hayashi,Ryûtarô Gomi,Jô Azumi,Nakajirô Tomita,Shichisaburô Amatsu'
#  'François Cluzet,Omar Sy,Anne Le Ny,Audrey Fleurot,Joséphine de Meaux,Clotilde Mollet,Alba Gaïa Bellugi,Cyril Mendy,Salimata Kamate,Absa Diatou Toure,Grégoire Oestermann,Dominique Daguier,François Caron,Christian Ameri,Thomas Solivérès,Dorothée Brière,Marie-Laure Descoureaux,Émilie Caen'
#  'Charles Chaplin,Paulette Goddard,Henry Bergman,Tiny Sandford,Chester Conklin,Hank Mann,Stanley Blystone,Al Ernest Garcia,Richard Alexander,Cecil Reynolds,Mira McKinney,Murdock MacQuarrie,Wilfred Lucas,Edward LeSaint,Fred Malatesta,Sammy Stein,Juana Sutton,Ted Oliver'
#  'Henry Fonda,Charles Bronson,Claudia Cardinale,Jason Robards,Gabriele Ferzetti,Paolo Stoppa,Woody Strode,Jack Elam,Keenan Wynn,Frank Wolff,Lionel Stander,Livio Andronico,Salvatore Basile,Aldo Berti,Joseph Bradley,Frank Braña,Marilù Carteny,Saturno Cerra'
#  'James Stewart,Grace Kelly,Wendell Corey,Thelma Ritter,Raymond Burr,Judith Evelyn,Ross Bagdasarian,Georgine Darcy,Sara Berner,Frank Cady,Jesslyn Fax,Rand Harper,Irene Winston,Havis Davenport,Jerry Antes,Barbara Bailey,Benny Bartlett,Nick Borgani'
#  'Philippe Noiret,Enzo Cannavale,Antonella Attili,Isa Danieli,Leo Gullotta,Marco Leonardi,Pupella Maggio,Agnese Nano,Leopoldo Trieste,Salvatore Cascio,Tano Cimarosa,Nicola Di Pinto,Roberta Lena,Nino Terzo,Jacques Perrin,Nellina Laganà,Turi Giuffrida,Mariella Lo Giudice'
#  'Sigourney Weaver,Tom Skerritt,John Hurt,Veronica Cartwright,Harry Dean Stanton,Ian Holm,Yaphet Kotto,Bolaji Badejo,Helen Horton,Eddie Powell'
#  'Charles Chaplin,Virginia Cherrill,Florence Lee,Harry Myers,Al Ernest Garcia,Hank Mann,Johnny Aber,Jack Alexander,T.S. Alexander,Victor Alexander,Albert Austin,Harry Ayers,Eddie Baker,Henry Bergman,Edward Biby,Betty Blair,Buster Brodie,Jeanne Carpenter'
#  'Martin Sheen,Marlon Brando,Robert Duvall,Frederic Forrest,Sam Bottoms,Laurence Fishburne,Albert Hall,Harrison Ford,Dennis Hopper,G.D. Spradlin,Jerry Ziesmer,Scott Glenn,Bo Byers,James Keane,Kerry Rossall,Ron McQueen,Tom Mason,Cynthia Wood'
#  'Guy Pearce,Carrie-Anne Moss,Joe Pantoliano,Mark Boone Junior,Russ Fega,Jorja Fox,Stephen Tobolowsky,Harriet Sansom Harris,Thomas Lennon,Callum Keith Rennie,Kimberly Campbell,Marianne Muellerleile,Larry Holden,Stephanie Searson,Buzz Visconti'
#  'Jamie Foxx,Christoph Waltz,Leonardo DiCaprio,Kerry Washington,Samuel L. Jackson,Walton Goggins,Dennis Christopher,James Remar,David Steen,Dana Gourrier,Nichole Galicia,Laura Cayouette,Ato Essandoh,Sammi Rotibi,Clay Donahue Fontenot,Escalante Lundy,Miriam F. Glover,Don Johnson'
#  'Harrison Ford,Karen Allen,Paul Freeman,John Rhys-Davies,Ronald Lacey,Denholm Elliott,Alfred Molina,Wolf Kahler,Anthony Higgins,Vic Tablian,Don Fellows,William Hootkins,Bill Reimbold,Fred Sorenson,Patrick Durkin,Matthew Scurfield,Malcolm Weaver,Sonny Caldinez'
#  'Ben Burtt,Elissa Knight,Jeff Garlin,Fred Willard,MacInTalk,John Ratzenberger,Kathy Najimy,Sigourney Weaver,Karleen Griffin,Kim Kopf,Niki McElroy,Garrett Palmer,Jessica Skelton,Kai Steel Smith,Michael Toy'
#  'Ulrich Mühe,Martina Gedeck,Sebastian Koch,Ulrich Tukur,Thomas Thieme,Hans-Uwe Bauer,Volkmar Kleinert,Matthias Brenner,Charly Hübner,Herbert Knaup,Bastian Trost,Marie Gruber,Volker Michalowski,Werner Daehn,Martin Brambach,Hubertus Hartmann,Thomas Arnold,Hinnerk Schönemann'
#  'William Holden,Gloria Swanson,Erich von Stroheim,Nancy Olson,Fred Clark,Lloyd Gough,Jack Webb,Franklyn Farnum,Larry J. Blake,Charles Dayton,Cecil B. DeMille,Hedda Hopper,Buster Keaton,Anna Q. Nilsson,H.B. Warner,Ray Evans,Jay Livingston,Fred Aldrich'
#  'Kirk Douglas,Ralph Meeker,Adolphe Menjou,George Macready,Wayne Morris,Richard Anderson,Joe Turkel,Christiane Kubrick,Jerry Hausner,Peter Capell,Emile Meyer,Bert Freed,Kem Dibbs,Timothy Carey,Fred Bell,John Stein,Harold Benedict,Leon Briggs'
#  'Jack Nicholson,Shelley Duvall,Danny Lloyd,Scatman Crothers,Barry Nelson,Philip Stone,Joe Turkel,Anne Jackson,Tony Burton,Lia Beldam,Billie Gibson,Barry Dennen,David Baxt,Manning Redwood,Lisa Burns,Louise Burns,Robin Pappas,Alison Coleridge'
#  'Charles Chaplin,Paulette Goddard,Jack Oakie,Reginald Gardiner,Henry Daniell,Billy Gilbert,Grace Hayle,Carter DeHaven,Maurice Moscovitch,Emma Dunn,Bernard Gorcey,Paul Weigel,Chester Conklin,Esther Michelson,Hank Mann,Florence Wright,Eddie Gribbon,Rudolph Anders'
#  'Robert Downey Jr.,Chris Hemsworth,Mark Ruffalo,Chris Evans,Scarlett Johansson,Don Cheadle,Benedict Cumberbatch,Tom Holland,Chadwick Boseman,Zoe Saldana,Karen Gillan,Tom Hiddleston,Paul Bettany,Elizabeth Olsen,Anthony Mackie,Sebastian Stan,Idris Elba,Danai Gurira'
#  "Tyrone Power,Marlene Dietrich,Charles Laughton,Elsa Lanchester,John Williams,Henry Daniell,Ian Wolfe,Torin Thatcher,Norma Varden,Una O'Connor,Francis Compton,Philip Tonge,Ruta Lee,Patrick Aherne,Don Ames,Walter Bacon,Eddie Baker,Benjie Bancroft"
#  'Sigourney Weaver,Michael Biehn,Carrie Henn,Paul Reiser,Lance Henriksen,Bill Paxton,William Hope,Jenette Goldstein,Al Matthews,Mark Rolston,Ricco Ross,Colette Hiller,Daniel Kash,Cynthia Dale Scott,Tip Tipping,Trevor Steedman,Paul Maxwell,Valerie Colgan'
#  'Shameik Moore,Jake Johnson,Hailee Steinfeld,Mahershala Ali,Brian Tyree Henry,Lily Tomlin,Luna Lauren Velez,Zoë Kravitz,John Mulaney,Kimiko Glenn,Nicolas Cage,Kathryn Hahn,Liev Schreiber,Chris Pine,Natalie Morales,Edwin R. Habacon,Oscar Isaac,Greta Lee'
#  'Kevin Spacey,Annette Bening,Thora Birch,Wes Bentley,Mena Suvari,Peter Gallagher,Allison Janney,Chris Cooper,Scott Bakula,Sam Robards,Barry Del Sherman,Ara Celi,John Cho,Fort Atkinson,Sue Casey,Kent Faulcon,Brenda Wehle,Lisa Cloud'
#  "Peter Sellers,George C. Scott,Sterling Hayden,Keenan Wynn,Slim Pickens,Peter Bull,James Earl Jones,Tracy Reed,Jack Creley,Frank Berry,Robert O'Neil,Glenn Beck,Roy Stephens,Shane Rimmer,Hal Galili,Paul Tamarin,Laurence Herder,Gordon Tanner"
#  'Christian Bale,Tom Hardy,Anne Hathaway,Gary Oldman,Joseph Gordon-Levitt,Marion Cotillard,Morgan Freeman,Michael Caine,Matthew Modine,Alon Aboutboul,Ben Mendelsohn,Burn Gorman,Daniel Sunjata,Aidan Gillen,Sam Kennard,Aliash Tepina,Nestor Carbonell,Brett Cullen'
#  'Choi Min-sik,Yoo Ji-tae,Kang Hye-jeong,Kim Byeong-Ok,Dae-han Ji,Dal-su Oh,Seung-shin Lee,Jin-Seo Yoon,Tae-kyung Oh,Yoo Yeon-Seok,Il-han Oo,Young-hee Lee,Young-ae Kim,Mi Mi Lee,Jae-Duk Han,Jung Ae Kwak,San Kim,Chae-soo Jang'
#  'Brad Pitt,Diane Kruger,Eli Roth,Mélanie Laurent,Christoph Waltz,Michael Fassbender,Daniel Brühl,Til Schweiger,Gedeon Burkhard,Jacky Ido,B.J. Novak,Omar Doom,August Diehl,Denis Ménochet,Sylvester Groth,Martin Wuttke,Mike Myers,Julie Dreyfus'
#  'F. Murray Abraham,Tom Hulce,Elizabeth Berridge,Roy Dotrice,Simon Callow,Christine Ebersole,Jeffrey Jones,Charles Kay,Kenneth McMillan,Kenny Baker,Lisbeth Bartlett,Barbara Bryne,Martin Cavina,Roderick Cook,Milan Demjanenko,Peter DiGesu,Richard Frank,Patrick Hines'
#  'Anthony Gonzalez,Gael García Bernal,Benjamin Bratt,Alanna Ubach,Renee Victor,Jaime Camil,Alfonso Arau,Herbert Siguenza,Gabriel Iglesias,Lombardo Boyar,Ana Ofelia Murguía,Natalia Cordova-Buckley,Selene Luna,Edward James Olmos,Sofía Espinosa,Carla Medina,Dyana Ortelli,Luis Valdez'
#  'Tom Hanks,Tim Allen,Don Rickles,Jim Varney,Wallace Shawn,John Ratzenberger,Annie Potts,John Morris,Erik von Detten,Laurie Metcalf,R. Lee Ermey,Sarah Rayne,Penn Jillette,Jack Angel,Spencer Aste,Greg Berg,Lisa Bradley,Kendall Cunningham'
#  'Joaquin Phoenix,Robert De Niro,Zazie Beetz,Frances Conroy,Brett Cullen,Shea Whigham,Bill Camp,Glenn Fleshler,Leigh Gill,Josh Pais,Rocco Luna,Marc Maron,Sondra James,Murphy Guyer,Douglas Hodge,Dante Pereira-Olson,Carrie Louise Putrello,Sharon Washington'
#  'Mel Gibson,Sophie Marceau,Patrick McGoohan,Angus Macfadyen,James Robinson,Sean Lawlor,Sandy Nelson,James Cosmo,Sean McGinley,Alan Tall,Andrew Weir,Gerda Stevenson,Ralph Riach,Mhairi Calvey,Brian Cox,Peter Hanly,Stephen Billington,Barry McGovern'
#  'Jürgen Prochnow,Herbert Grönemeyer,Klaus Wennemann,Hubertus Bengsch,Martin Semmelrogge,Bernd Tauber,Erwin Leder,Martin May,Heinz Hoenig,Uwe Ochsenknecht,Claude-Oliver Rudolph,Jan Fedder,Ralf Richter,Joachim Bernhard,Oliver Stritzel,Konrad Becker,Lutz Schnell,Martin Hemme'
#  'Robert Downey Jr.,Chris Evans,Mark Ruffalo,Chris Hemsworth,Scarlett Johansson,Jeremy Renner,Don Cheadle,Paul Rudd,Benedict Cumberbatch,Chadwick Boseman,Brie Larson,Tom Holland,Karen Gillan,Zoe Saldana,Evangeline Lilly,Tessa Thompson,Rene Russo,Elizabeth Olsen'
# ...
# Let the Awe and Mystery of a Journey Unlike Any Other Begin                                                                                                                                                                                                                                                                         1
# Seven Total Strangers Team Up For The Perfect Crime. They Don't Know Each Other's Name. But They've Got Each Other's Color                                                                                                                                                                                                          1
# Inside everyone is a frontier waiting to be discovered.                                                                                                                                                                                                                                                                             1
# Name: count, Length: 250, dtype: int64
# Frequency distribution for 'budget':
# budget
# Not Available    39
# 25000000          8
# 15000000          8
# 3000000           7
# 6000000           6
#                  ..
# EM 32000000       1
# 72000000          1
# 250000000         1
# 1800000           1
# 325000            1
# Name: count, Length: 128, dtype: int64
# Frequency distribution for 'box_office':
# box_office
# Not Available    30
# 28884504          1
# 31207             1
# 180906076         1
# 81379             1
#                  ..
# 170005875         1
# 5473337           1
# 60262836          1
# 2000288           1
# 424208848         1
# Name: count, Length: 221, dtype: int64
# Frequency distribution for 'casts':
# casts
# Tim Robbins,Morgan Freeman,Bob Gunton,William Sadler,Clancy Brown,Gil Bellows,Mark Rolston,James Whitmore,Jeffrey DeMunn,Larry Brandenburg,Neil Giuntoli,Brian Libby,David Proval,Joseph Ragno,Jude Ciccolella,Paul McCrane,Renee Blaine,Scott Mann                                                     1
# Hitoshi Takagi,Noriko Hidaka,Chika Sakamoto,Shigesato Itoi,Sumi Shimamoto,Tanie Kitabayashi,Hiroko Maruyama,Machiko Washio,Reiko Suzuki,Masashi Hirose,Toshiyuki Amagasa,Shigeru Chiba,Naoki Tatsuta,Tarako,Tomohiro Nishimura,Mitsuko Ishida,Chie Kôjiro,Daiki Nakamura                                1
# Clark Gable,Vivien Leigh,Thomas Mitchell,Barbara O'Neil,Evelyn Keyes,Ann Rutherford,George Reeves,Fred Crane,Hattie McDaniel,Oscar Polk,Butterfly McQueen,Victor Jory,Everett Brown,Howard Hickman,Alicia Rhett,Leslie Howard,Olivia de Havilland,Rand Brooks                                           1
# Jason Flemyng,Dexter Fletcher,Nick Moran,Jason Statham,Steven Mackintosh,Nicholas Rowe,Nick Marcq,Charles Forbes,Vinnie Jones,Lenny McLean,Peter McNicholl,P.H. Moriarty,Frank Harper,Steve Sweeney,Huggy Leaver,Ronnie Fox,Tony McMahon,Stephen Marcus                                                 1
# Amy Poehler,Bill Hader,Lewis Black,Mindy Kaling,Phyllis Smith,Richard Kind,Kaitlyn Dias,Diane Lane,Kyle MacLachlan,Paula Poundstone,Bobby Moynihan,Paula Pell,Dave Goelz,Frank Oz,Josh Cooley,Flea,John Ratzenberger,Carlos Alazraqui                                                                   1
#                                                                                                                                                                                                                                                                                                        ..
# Mark Hamill,Harrison Ford,Carrie Fisher,Billy Dee Williams,Anthony Daniels,Peter Mayhew,Sebastian Shaw,Ian McDiarmid,Frank Oz,James Earl Jones,David Prowse,Alec Guinness,Kenny Baker,Michael Pennington,Kenneth Colley,Michael Carter,Denis Lawson,Tim Rose                                            1
# Jim Carrey,Kate Winslet,Tom Wilkinson,Gerry Robert Byrne,Elijah Wood,Thomas Jay Ryan,Mark Ruffalo,Jane Adams,David Cross,Kirsten Dunst,Ryan Whitney,Debbon Ayer,Amir Ali Said,Brian Price,Paulie Litt,Josh Flitter,Lola Daehler,Deirdre O'Connell                                                       1
# Keir Dullea,Gary Lockwood,William Sylvester,Daniel Richter,Leonard Rossiter,Margaret Tyzack,Robert Beatty,Sean Sullivan,Douglas Rain,Frank Miller,Bill Weston,Ed Bishop,Glenn Beck,Alan Gifford,Ann Gillis,Edwina Carroll,Penny Brahms,Heather Downham                                                  1
# Harvey Keitel,Tim Roth,Michael Madsen,Chris Penn,Steve Buscemi,Lawrence Tierney,Randy Brooks,Kirk Baltz,Edward Bunker,Quentin Tarantino,Rich Turner,David Steen,Tony Cosmo,Stevo Polyi,Michael Sottile,Robert Ruth,Lawrence Bender,Linda Kaye                                                           1
# Kevin Costner,Mary McDonnell,Graham Greene,Rodney A. Grant,Floyd 'Red Crow' Westerman,Tantoo Cardinal,Robert Pastorelli,Charles Rocket,Maury Chaykin,Jimmy Herman,Nathan Lee Chasing His Horse,Michael Spears,Jason R. Lone Hill,Tony Pierce,Doris Leader Charge,Tom Everett,Larry Joshua,Kirk Baltz    1
# Name: count, Length: 250, dtype: int64
# Frequency distribution for 'directors':
# directors
# Martin Scorsese       7
# Christopher Nolan     7
# Steven Spielberg      7
# Stanley Kubrick       7
# Akira Kurosawa        7
#                      ..
# Jean-Pierre Jeunet    1
# Orson Welles          1
# Thomas Vinterberg     1
# Elem Klimov           1
# Kevin Costner         1
# Name: count, Length: 160, dtype: int64
# Frequency distribution for 'writers':
# writers
# Charles Chaplin                                4
# J.R.R. Tolkien,Fran Walsh,Philippa Boyens      3
# Ingmar Bergman                                 3
# Stephen King,Frank Darabont                    2
# Christopher Markus,Stephen McFeely,Stan Lee    2
#                                               ..
# Thea von Harbou,Fritz Lang,Egon Jacobsohn      1
# Robert Bolt,Michael Wilson                     1
# Ernest Lehman                                  1
# Alec Coppel,Samuel A. Taylor,Pierre Boileau    1
# Michael Blake                                  1
# Name: count, Length: 233, dtype: int64
# Frequency distribution for 'genre_0':
# genre_0
# Drama        68
# Action       45
# Crime        35
# Biography    23
# Comedy       23
# Animation    23
# Adventure    22
# Horror        4
# Mystery       4
# Western       2
# Film-Noir     1
# Name: count, dtype: int64
# Frequency distribution for 'genre_1':
# genre_1
# Drama        82
# Adventure    33
# Romance      15
# Mystery      14
# Crime        13
# Thriller     13
# Comedy       11
# War           9
# Sci-Fi        7
# Family        6
# Biography     6
# Action        5
# Western       3
# Music         2
# Film-Noir     2
# Fantasy       2
# Sport         2
# Horror        1
# Musical       1
# Name: count, dtype: int64
# Frequency distribution for 'genre_2':
# genre_2
# Drama        27
# Thriller     17
# War          14
# Sci-Fi       13
# Mystery      13
# Fantasy      12
# Comedy       11
# History      10
# Romance       8
# Family        7
# Adventure     5
# Crime         3
# Sport         3
# Music         2
# Western       2
# Film-Noir     1
# Name: count, dtype: int64
# Frequency distribution for 'writers_0':
# writers_0
# Stanley Kubrick       6
# Akira Kurosawa        5
# Charles Chaplin       5
# Quentin Tarantino     5
# Stephen King          4
#                      ..
# Alec Coppel           1
# Guillaume Laurant     1
# Jim Cash              1
# Lin-Manuel Miranda    1
# Michael Blake         1
# Name: count, Length: 199, dtype: int64
# Frequency distribution for 'writers_1':
# writers_1
# Christopher Nolan     4
# Shinobu Hashimoto     3
# George Lucas          3
# Fran Walsh            3
# Frank Darabont        2
#                      ..
# Samuel A. Taylor      1
# Jean-Pierre Jeunet    1
# Anthony Burgess       1
# Raymond Chandler      1
# John Musker           1
# Name: count, Length: 170, dtype: int64
# Frequency distribution for 'writers_2':
# writers_2
# Philippa Boyens       3
# Stan Lee              3
# David S. Goyer        2
# Park Chan-wook        2
# Hideo Oguni           2
#                      ..
# Eijirô Hisaita        1
# Lee Unkrich           1
# Vidhu Vinod Chopra    1
# Piero De Bernardi     1
# Ted Elliott           1
# Name: count, Length: 100, dtype: int64
# Frequency distribution for 'casts_0':
# casts_0
# Robert De Niro       6
# Leonardo DiCaprio    5
# Charles Chaplin      5
# Tom Hanks            5
# Christian Bale       4
#                     ..
# Jack Lemmon          1
# Malcolm McDowell     1
# Fred MacMurray       1
# Matthew Modine       1
# Kevin Costner        1
# Name: count, Length: 182, dtype: int64
# Frequency distribution for 'casts_1':
# casts_1
# Harrison Ford        3
# Robert De Niro       3
# Matt Damon           3
# Julie Delpy          2
# Alec Guinness        2
#                     ..
# Eva Marie Saint      1
# Kim Novak            1
# Nobuo Kaneko         1
# Mathieu Kassovitz    1
# Mary McDonnell       1
# Name: count, Length: 229, dtype: int64
# Frequency distribution for 'casts_2':
# casts_2
# Mark Ruffalo              3
# Joe Pesci                 3
# Carrie Fisher             3
# Tatsuya Nakadai           2
# Robert Duvall             2
#                          ..
# Liubomiras Laucevicius    1
# Annika Wedderkopp         1
# Dorothy Comingore         1
# Inge Landgut              1
# Graham Greene             1
# Name: count, Length: 238, dtype: int64
# Frequency distribution for 'casts_3':
# casts_3
# Olivia Williams        2
# Paul Reiser            2
# Christopher Plummer    2
# Billy Dee Williams     2
# Terry Gilliam          2
#                       ..
# Chris Penn             1
# Vladas Bagdonas        1
# Lasse Fogelstrøm       1
# Agnes Moorehead        1
# Rodney A. Grant        1
# Name: count, Length: 240, dtype: int64
# Frequency distribution for 'casts_4':
# casts_4
# Scarlett Johansson            2
# James Cromwell                2
# Anthony Daniels               2
# Don Rickles                   2
# Luigi Pistilli                2
#                              ..
# Leonard Rossiter              1
# Steve Buscemi                 1
# Jüri Lumiste                  1
# Susse Wold                    1
# Floyd 'Red Crow' Westerman    1
# Name: count, Length: 242, dtype: int64
# Frequency distribution for 'casts_5':
# casts_5
# Daisuke Katô           2
# Gary Oldman            2
# Hank Mann              2
# Adam Goldberg          2
# John Ratzenberger      2
#                       ..
# Lawrence Tierney       1
# Viktors Lorencs        1
# Anne Louise Hassing    1
# Ray Collins            1
# Tantoo Cardinal        1
# Name: count, Length: 244, dtype: int64
# Frequency distribution for 'casts_6':
# casts_6
# Cillian Murphy       2
# Morgan Freeman       2
# Allison Janney       2
# Sean Astin           2
# Joe Turkel           2
#                     ..
# Kazimir Rabetsky     1
# Lars Ranthe          1
# Erskine Sanford      1
# Friedrich Gnaß       1
# Robert Pastorelli    1
# Name: count, Length: 244, dtype: int64
# Frequency distribution for 'casts_7':
# casts_7
# Sala Baker           2
# James Cosmo          2
# Carol Cleveland      2
# John Ratzenberger    2
# Brian Howe           2
#                     ..
# Ian McDiarmid        1
# Jane Adams           1
# Sean Sullivan        1
# Kirk Baltz           1
# Charles Rocket       1
# Name: count, Length: 243, dtype: int64
# Frequency distribution for 'casts_8':
# casts_8
# Frank Oz                3
# Jeffrey DeMunn          1
# Frank John Hughes       1
# Vinnie Jones            1
# Kyle MacLachlan         1
#                        ..
# Mohammad Al Abdallah    1
# David Cross             1
# Douglas Rain            1
# Edward Bunker           1
# Maury Chaykin           1
# Name: count, Length: 246, dtype: int64
# Frequency distribution for 'casts_9':
# casts_9
# Larry Brandenburg     1
# Masashi Hirose        1
# Oscar Polk            1
# Lenny McLean          1
# Paula Poundstone      1
#                      ..
# Mohamad Abdellatif    1
# James Earl Jones      1
# Kirsten Dunst         1
# Frank Miller          1
# Jimmy Herman          1
# Name: count, Length: 248, dtype: int64
# Frequency distribution for 'casts_10':
# casts_10
# Nobuo Nakamura                  2
# R. Lee Ermey                    2
# Neil Giuntoli                   1
# Toshiyuki Amagasa               1
# Bobby Moynihan                  1
#                                ..
# Ryan Whitney                    1
# Bill Weston                     1
# Rich Turner                     1
# Aleksandr Berda                 1
# Nathan Lee Chasing His Horse    1
# Name: count, Length: 244, dtype: int64
# Frequency distribution for 'casts_11':
# casts_11
# Brian Libby         1
# Charles Scorsese    1
# Victor Jory         1
# P.H. Moriarty       1
# Paula Pell          1
#                    ..
# Yûnosuke Itô        1
# Hampig Abraham      1
# Alec Guinness       1
# Debbon Ayer         1
# Michael Spears      1
# Name: count, Length: 244, dtype: int64
# Frequency distribution for 'casts_12':
# casts_12
# Larry Holden          2
# David Proval          1
# Naoki Tatsuta         1
# Frank Harper          1
# Dave Goelz            1
#                      ..
# Jamil Ahmad           1
# Kenny Baker           1
# Amir Ali Said         1
# Glenn Beck            1
# Jason R. Lone Hill    1
# Name: count, Length: 243, dtype: int64
# Frequency distribution for 'casts_13':
# casts_13
# Joseph Ragno          1
# Åke Fridell           1
# Clive Ashborn         1
# Howard Hickman        1
# Steve Sweeney         1
#                      ..
# Minoru Chiaki         1
# Mohamad Akkar         1
# Michael Pennington    1
# Brian Price           1
# Tony Pierce           1
# Name: count, Length: 243, dtype: int64
# Frequency distribution for 'casts_14':
# casts_14
# Josh Cooley            2
# Eijirô Tôno            2
# Jude Ciccolella        1
# Xia Soua Chang         1
# Emma Field-Rayner      1
#                       ..
# Teddy Newton           1
# Elias Akobegia         1
# Kenneth Colley         1
# Paulie Litt            1
# Doris Leader Charge    1
# Name: count, Length: 240, dtype: int64
# Frequency distribution for 'casts_15':
# casts_15
# Paul McCrane       1
# Al Martino         1
# Ian Burfield       1
# Leslie Howard      1
# Ronnie Fox         1
#                   ..
# Riman Al Rafeea    1
# Michael Carter     1
# Josh Flitter       1
# Edwina Carroll     1
# Tom Everett        1
# Name: count, Length: 240, dtype: int64
# Frequency distribution for 'casts_16':
# casts_16
# Renee Blaine           1
# Morgana King           1
# Mark Phoenix           1
# Olivia de Havilland    1
# Tony McMahon           1
#                       ..
# Legamett Alamou        1
# Denis Lawson           1
# Lola Daehler           1
# Penny Brahms           1
# Larry Joshua           1
# Name: count, Length: 240, dtype: int64
# Frequency distribution for 'casts_17':
# casts_17
# Christopher Lee      2
# Scott Mann           1
# Greg Trzaskoma       1
# Rand Brooks          1
# Stephen Marcus       1
#                     ..
# Tim Rose             1
# Deirdre O'Connell    1
# Heather Downham      1
# Linda Kaye           1
# Kirk Baltz           1
# Name: count, Length: 239, dtype: int64
# Frequency distribution for 'directors_0':
# directors_0
# Martin Scorsese       7
# Stanley Kubrick       7
# Christopher Nolan     7
# Akira Kurosawa        7
# Steven Spielberg      7
#                      ..
# Joseph Kosinski       1
# Jean-Pierre Jeunet    1
# Orson Welles          1
# Thomas Vinterberg     1
# Kevin Costner         1
# Name: count, Length: 154, dtype: int64
# Frequency distribution for 'directors_1':
# directors_1
# Joe Russo                             2
# Ethan Coen(uncredited)                2
# George Cukor(uncredited)              2
# Lilly Wachowski                       1
# Lee Unkrich(co-director)              1
# Jan Pinkava(co-director)              1
# David Silverman(co-director)          1
# Chris Sanders                         1
# Buster Keaton                         1
# Carlos Martínez López(co-director)    1
# Ronnie Del Carmen(co-director)        1
# Joel Coen                             1
# Kátia Lund(co-director)               1
# Terry Jones                           1
# Amole Gupte(uncredited)               1
# Bob Peterson(co-director)             1
# Gene Kelly                            1
# Adrian Molina(co-directed by)         1
# Peter Ramsey                          1
# Éric Toledano                         1
# Rob Minkoff                           1
# John Musker                           1
# Name: count, dtype: int64
# Frequency distribution for 'directors_2':
# directors_2
# Rodney Rothman              1
# Sam Wood(uncredited)        1
# Lee Unkrich(co-director)    1
# Mervyn LeRoy(uncredited)    1
# Name: count, dtype: int64

# %%
# prompt: give the code to read the IMDB Top 250 Movies.csv and parse with numpy

import numpy as np
import pandas as pd

# Read the IMDB Top 250 Movies.csv file into a Pandas DataFrame
df = pd.read_csv('/content/sample_data/IMDB Top 250 Movies.csv')

# Parse a copy of the DataFrame with NumPy
new_df = df[:]

# Create array with the genre column
new_df.genre = df.genre.str.split(',')

#explode the genre, this will create a row for each different genre
new_df = new_df.explode(['genre'])

# Print the data
#print(df.head())
print(new_df.head())
# Out:
#    rank                      name  year  rating   genre certificate run_time  \
# 0     1  The Shawshank Redemption  1994     9.3   Drama           R   2h 22m
# 1     2             The Godfather  1972     9.2   Crime           R   2h 55m
# 1     2             The Godfather  1972     9.2   Drama           R   2h 55m
# 2     3           The Dark Knight  2008     9.0  Action       PG-13   2h 32m
# 2     3           The Dark Knight  2008     9.0   Crime       PG-13   2h 32m
#
#                                              tagline     budget  box_office  \
# 0  Fear can hold you prisoner. Hope can set you f...   25000000    28884504
# 1                         An offer you can't refuse.    6000000   250341816
# 1                         An offer you can't refuse.    6000000   250341816
# 2                                    Why So Serious?  185000000  1006234167
# 2                                    Why So Serious?  185000000  1006234167
#
#                                                casts             directors  \
# 0  Tim Robbins,Morgan Freeman,Bob Gunton,William ...        Frank Darabont
# 1  Marlon Brando,Al Pacino,James Caan,Diane Keato...  Francis Ford Coppola
# 1  Marlon Brando,Al Pacino,James Caan,Diane Keato...  Francis Ford Coppola
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...     Christopher Nolan
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...     Christopher Nolan
#
#                                            writers
# 0                      Stephen King,Frank Darabont
# 1                  Mario Puzo,Francis Ford Coppola
# 1                  Mario Puzo,Francis Ford Coppola
# 2  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 2  Jonathan Nolan,Christopher Nolan,David S. Goyer

# %%
# Getting all unique genre
unique_genres = new_df['genre'].unique()
# get the count
genre_counts = new_df['genre'].value_counts()

new_df['genre'].value_counts().plot.bar()
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title(f"Distribution of Genres")
plt.show()

# Print the unique genres and their counts
for genre, count in zip(unique_genres, genre_counts):
  print(f"Genre: {genre}, Count: {count}")

print(len(unique_genres))
# Out:
# Genre: Drama, Count: 177
# Genre: Crime, Count: 60
# Genre: Action, Count: 51
# Genre: Biography, Count: 50
# Genre: History, Count: 45
# Genre: Adventure, Count: 31
# Genre: Western, Count: 30
# Genre: Romance, Count: 29
# Genre: Sci-Fi, Count: 23
# Genre: Fantasy, Count: 23
# Genre: Mystery, Count: 23
# Genre: Family, Count: 20
# Genre: Thriller, Count: 14
# Genre: War, Count: 13
# Genre: Comedy, Count: 10
# Genre: Animation, Count: 7
# Genre: Music, Count: 5
# Genre: Horror, Count: 5
# Genre: Film-Noir, Count: 4
# Genre: Musical, Count: 4
# Genre: Sport, Count: 1
# 21

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read the IMDB Top 250 Movies.csv file into a Pandas DataFrame
df = pd.read_csv('/content/sample_data/IMDB Top 250 Movies.csv')

column_names = df.columns.tolist()

# Use a dictionary as the data structure
ds_movies = {}
for index, row in df.iterrows():
  ds_movies[row["rank"]] = {}
  for column in column_names:
    if column not in ["genre", "casts", "directors", "writers"]:
      ds_movies[row["rank"]][column] = row[column]
    else:
      ds_movies[row["rank"]][column] = row[column].title().split(",")

for movie in ds_movies.items():
  print(movie)
# Out:
# (1, {'rank': 1, 'name': 'The Shawshank Redemption', 'year': 1994, 'rating': 9.3, 'genre': ['Drama'], 'certificate': 'R', 'run_time': '2h 22m', 'tagline': 'Fear can hold you prisoner. Hope can set you free.', 'budget': '25000000', 'box_office': '28884504', 'casts': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler', 'Clancy Brown', 'Gil Bellows', 'Mark Rolston', 'James Whitmore', 'Jeffrey Demunn', 'Larry Brandenburg', 'Neil Giuntoli', 'Brian Libby', 'David Proval', 'Joseph Ragno', 'Jude Ciccolella', 'Paul Mccrane', 'Renee Blaine', 'Scott Mann'], 'directors': ['Frank Darabont'], 'writers': ['Stephen King', 'Frank Darabont']})
# (2, {'rank': 2, 'name': 'The Godfather', 'year': 1972, 'rating': 9.2, 'genre': ['Crime', 'Drama'], 'certificate': 'R', 'run_time': '2h 55m', 'tagline': "An offer you can't refuse.", 'budget': '6000000', 'box_office': '250341816', 'casts': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton', 'Richard S. Castellano', 'Robert Duvall', 'Sterling Hayden', 'John Marley', 'Richard Conte', 'Al Lettieri', 'Abe Vigoda', 'Talia Shire', 'Gianni Russo', 'John Cazale', 'Rudy Bond', 'Al Martino', 'Morgana King', 'Lenny Montana'], 'directors': ['Francis Ford Coppola'], 'writers': ['Mario Puzo', 'Francis Ford Coppola']})
# (3, {'rank': 3, 'name': 'The Dark Knight', 'year': 2008, 'rating': 9.0, 'genre': ['Action', 'Crime', 'Drama'], 'certificate': 'PG-13', 'run_time': '2h 32m', 'tagline': 'Why So Serious?', 'budget': '185000000', 'box_office': '1006234167', 'casts': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine', 'Maggie Gyllenhaal', 'Gary Oldman', 'Morgan Freeman', 'Monique Gabriela Curnen', 'Ron Dean', 'Cillian Murphy', 'Chin Han', 'Nestor Carbonell', 'Eric Roberts', 'Ritchie Coster', 'Anthony Michael Hall', 'Keith Szarabajka', 'Colin Mcfarlane', 'Joshua Harto'], 'directors': ['Christopher Nolan'], 'writers': ['Jonathan Nolan', 'Christopher Nolan', 'David S. Goyer']})
# (4, {'rank': 4, 'name': 'The Godfather Part II', 'year': 1974, 'rating': 9.0, 'genre': ['Crime', 'Drama'], 'certificate': 'R', 'run_time': '3h 22m', 'tagline': "All the power on earth can't change destiny.", 'budget': '13000000', 'box_office': '47961919', 'casts': ['Al Pacino', 'Robert De Niro', 'Robert Duvall', 'Diane Keaton', 'John Cazale', 'Talia Shire', 'Lee Strasberg', 'Michael V. Gazzo', 'G.D. Spradlin', 'Richard Bright', 'Gastone Moschin', 'Tom Rosqui', 'Bruno Kirby', 'Frank Sivero', 'Francesca De Sapio', 'Morgana King', 'Marianna Hill', 'Leopoldo Trieste'], 'directors': ['Francis Ford Coppola'], 'writers': ['Francis Ford Coppola', 'Mario Puzo']})
# (5, {'rank': 5, 'name': '12 Angry Men', 'year': 1957, 'rating': 9.0, 'genre': ['Crime', 'Drama'], 'certificate': 'Approved', 'run_time': '1h 36m', 'tagline': 'Life Is In Their Hands -- Death Is On Their Minds!', 'budget': '350000', 'box_office': '955', 'casts': ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam', 'John Fiedler', 'E.G. Marshall', 'Jack Klugman', 'Edward Binns', 'Jack Warden', 'Joseph Sweeney', 'Ed Begley', 'George Voskovec', 'Robert Webber', 'Rudy Bond', 'Tom Gorman', 'James Kelly', 'Billy Nelson', 'John Savoca', 'Walter Stocker'], 'directors': ['Sidney Lumet'], 'writers': ['Reginald Rose']})
# (6, {'rank': 6, 'name': "Schindler's List", 'year': 1993, 'rating': 9.0, 'genre': ['Biography', 'Drama', 'History'], 'certificate': 'R', 'run_time': '3h 15m', 'tagline': 'Whoever saves one life, saves the world entire.', 'budget': '22000000', 'box_office': '322161245', 'casts': ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley', 'Caroline Goodall', 'Jonathan Sagall', 'Embeth Davidtz', 'Malgorzata Gebel', 'Shmuel Levy', 'Mark Ivanir', 'Béatrice Macola', 'Andrzej Seweryn', 'Friedrich Von Thun', 'Krzysztof Luft', 'Harry Nehring', 'Norbert Weisser', 'Adi Nitzan', 'Michael Schneider', 'Miri Fabian'], 'directors': ['Steven Spielberg'], 'writers': ['Thomas Keneally', 'Steven Zaillian']})
# (7, {'rank': 7, 'name': 'The Lord of the Rings: The Return of the King', 'year': 2003, 'rating': 9.0, 'genre': ['Action', 'Adventure', 'Drama'], 'certificate': 'PG-13', 'run_time': '3h 21m', 'tagline': 'The eye of the enemy is moving.', 'budget': '94000000', 'box_office': '1146457748', 'casts': ['Elijah Wood', 'Viggo Mortensen', 'Ian Mckellen', 'Orlando Bloom', 'Noel Appleby', 'Ali Astin', 'Sean Astin', 'David Aston', 'John Bach', 'Sean Bean', 'Cate Blanchett', 'Billy Boyd', 'Sadwyn Brophy', 'Alistair Browning', 'Marton Csokas', 'Richard Edge', 'Jason Fitch', 'Bernard Hill'], 'directors': ['Peter Jackson'], 'writers': ['J.R.R. Tolkien', 'Fran Walsh', 'Philippa Boyens']})
# (8, {'rank': 8, 'name': 'Pulp Fiction', 'year': 1994, 'rating': 8.9, 'genre': ['Crime', 'Drama'], 'certificate': 'R', 'run_time': '2h 34m', 'tagline': "Girls like me don't make invitations like this to just anyone!", 'budget': '8000000', 'box_office': '213928762', 'casts': ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson', 'Bruce Willis', 'Tim Roth', 'Amanda Plummer', 'Laura Lovelace', 'Phil Lamarr', 'Frank Whaley', 'Burr Steers', 'Ving Rhames', 'Paul Calderon', 'Bronagh Gallagher', 'Rosanna Arquette', 'Eric Stoltz', 'Jerome Patrick Hoban', 'Michael Gilden', 'Gary Shorelle'], 'directors': ['Quentin Tarantino'], 'writers': ['Quentin Tarantino', 'Roger Avary']})
# (9, {'rank': 9, 'name': 'The Lord of the Rings: The Fellowship of the Ring', 'year': 2001, 'rating': 8.8, 'genre': ['Action', 'Adventure', 'Drama'], 'certificate': 'PG-13', 'run_time': '2h 58m', 'tagline': 'The Legend Comes to Life', 'budget': '93000000', 'box_office': '898204420', 'casts': ['Elijah Wood', 'Ian Mckellen', 'Orlando Bloom', 'Sean Bean', 'Alan Howard', 'Noel Appleby', 'Sean Astin', 'Sala Baker', 'Billy Boyd', 'Andy Serkis', 'Marton Csokas', 'Viggo Mortensen', 'Megan Edwards', 'Michael Elsworth', 'Cate Blanchett', 'Mark Ferguson', 'Ian Holm', 'Christopher Lee'], 'directors': ['Peter Jackson'], 'writers': ['J.R.R. Tolkien', 'Fran Walsh', 'Philippa Boyens']})
# (10, {'rank': 10, 'name': 'The Good, the Bad and the Ugly', 'year': 1966, 'rating': 8.8, 'genre': ['Adventure', 'Western'], 'certificate': 'Approved', 'run_time': '2h 58m', 'tagline': "They formed an alliance of hate to steal a fortune in dead man's gold", 'budget': '1200000', 'box_office': '25253887', 'casts': ['Clint Eastwood', 'Eli Wallach', 'Lee Van Cleef', 'Aldo Giuffrè', 'Luigi Pistilli', 'Rada Rassimov', 'Enzo Petito', 'Claudio Scarchilli', 'John Bartha', 'Livio Lorenzon', 'Antonio Casale', 'Sandro Scarchilli', 'Benito Stefanelli', 'Angelo Novi', 'Antonio Casas', 'Aldo Sambrell', 'Al Mulock', 'Sergio Mendizábal'], 'directors': ['Sergio Leone'], 'writers': ['Luciano Vincenzoni', 'Sergio Leone', 'Agenore Incrocci']})
# (11, {'rank': 11, 'name': 'Forrest Gump', 'year': 1994, 'rating': 8.8, 'genre': ['Drama', 'Romance'], 'certificate': 'PG-13', 'run_time': '2h 22m', 'tagline': 'The story of a lifetime.', 'budget': '55000000', 'box_office': '678226465', 'casts': ['Tom Hanks', 'Robin Wright', 'Gary Sinise', 'Sally Field', 'Rebecca Williams', 'Michael Conner Humphreys', 'Harold G. Herthum', 'George Kelly', 'Bob Penny', 'John Randall', 'Sam Anderson', 'Margo Moorer', 'Ione M. Telech', 'Christine Seabrook', 'John Worsham', 'Peter Dobson', 'Siobhan Fallon Hogan', 'Alexander Zemeckis'], 'directors': ['Robert Zemeckis'], 'writers': ['Winston Groom', 'Eric Roth']})
# (12, {'rank': 12, 'name': 'Fight Club', 'year': 1999, 'rating': 8.8, 'genre': ['Drama'], 'certificate': 'R', 'run_time': '2h 19m', 'tagline': "How much can you know about yourself if you've never been in a fight?", 'budget': '63000000', 'box_office': '101209702', 'casts': ['Brad Pitt', 'Edward Norton', 'Meat Loaf', 'Zach Grenier', 'Richmond Arquette', 'David Andrews', 'George Maguire', 'Eugenie Bondurant', 'Christina Cabot', 'Helena Bonham Carter', "Sydney 'Big Dawg' Colston", 'Rachel Singer', 'Christie Cronenweth', 'Tim Dezarn', 'Ezra Buzzington', 'Dierdre Downing-Jackson', 'Bob Stephenson', 'Charlie Dell'], 'directors': ['David Fincher'], 'writers': ['Chuck Palahniuk', 'Jim Uhls']})
# (13, {'rank': 13, 'name': 'The Lord of the Rings: The Two Towers', 'year': 2002, 'rating': 8.8, 'genre': ['Action', 'Adventure', 'Drama'], 'certificate': 'PG-13', 'run_time': '2h 59m', 'tagline': 'A New Power Is Rising.', 'budget': '94000000', 'box_office': '947944270', 'casts': ['Elijah Wood', 'Ian Mckellen', 'Viggo Mortensen', 'Orlando Bloom', 'Bruce Allpress', 'Sean Astin', 'John Bach', 'Sala Baker', 'Cate Blanchett', 'Billy Boyd', 'Jed Brophy', 'Sam Comery', 'Brad Dourif', 'Calum Gittins', 'Bernard Hill', 'Bruce Hopkins', 'Paris Howe Strewe', 'Christopher Lee'], 'directors': ['Peter Jackson'], 'writers': ['J.R.R. Tolkien', 'Fran Walsh', 'Philippa Boyens']})
# (14, {'rank': 14, 'name': 'Inception', 'year': 2010, 'rating': 8.8, 'genre': ['Action', 'Adventure', 'Sci-Fi'], 'certificate': 'PG-13', 'run_time': '2h 28m', 'tagline': 'Your mind is the scene of the crime', 'budget': '160000000', 'box_office': '836848102', 'casts': ['Leonardo Dicaprio', 'Joseph Gordon-Levitt', 'Elliot Page', 'Ken Watanabe', 'Tom Hardy', 'Dileep Rao', 'Cillian Murphy', 'Tom Berenger', 'Marion Cotillard', 'Pete Postlethwaite', 'Michael Caine', 'Lukas Haas', 'Tai-Li Lee', 'Claire Geare', 'Magnus Nolan', 'Taylor Geare', 'Johnathan Geare', 'Tohoru Masamune'], 'directors': ['Christopher Nolan'], 'writers': ['Christopher Nolan']})
# (15, {'rank': 15, 'name': 'Star Wars: Episode V - The Empire Strikes Back', 'year': 1980, 'rating': 8.7, 'genre': ['Action', 'Adventure', 'Fantasy'], 'certificate': 'PG', 'run_time': '2h 4m', 'tagline': 'The Adventure Continues...', 'budget': '18000000', 'box_office': '538375067', 'casts': ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher', 'Billy Dee Williams', 'Anthony Daniels', 'David Prowse', 'Peter Mayhew', 'Kenny Baker', 'Frank Oz', 'Alec Guinness', 'Jeremy Bulloch', 'John Hollis', 'Jack Purvis', 'Des Webb', 'Clive Revill', 'Kenneth Colley', 'Julian Glover', 'Michael Sheard'], 'directors': ['Irvin Kershner'], 'writers': ['Leigh Brackett', 'Lawrence Kasdan', 'George Lucas']})
# (16, {'rank': 16, 'name': 'The Matrix', 'year': 1999, 'rating': 8.7, 'genre': ['Action', 'Sci-Fi'], 'certificate': 'R', 'run_time': '2h 16m', 'tagline': 'Free your mind', 'budget': '63000000', 'box_office': '467222728', 'casts': ['Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss', 'Hugo Weaving', 'Gloria Foster', 'Joe Pantoliano', 'Marcus Chong', 'Julian Arahanga', 'Matt Doran', 'Belinda Mcclory', 'Anthony Ray Parker', 'Paul Goddard', 'Robert Taylor', 'David Aston', 'Marc Aden Gray', 'Ada Nicodemou', 'Deni Gordon', 'Rowan Witt'], 'directors': ['Lana Wachowski', 'Lilly Wachowski'], 'writers': ['Lilly Wachowski', 'Lana Wachowski']})
# (17, {'rank': 17, 'name': 'Goodfellas', 'year': 1990, 'rating': 8.7, 'genre': ['Biography', 'Crime', 'Drama'], 'certificate': 'R', 'run_time': '2h 25m', 'tagline': '"As far back as I can remember, I\'ve always wanted to be a gangster." -- Henry Hill, Brooklyn, N.Y. 1955.', 'budget': '25000000', 'box_office': '47036784', 'casts': ['Robert De Niro', 'Ray Liotta', 'Joe Pesci', 'Lorraine Bracco', 'Paul Sorvino', 'Frank Sivero', 'Tony Darrow', 'Mike Starr', 'Frank Vincent', 'Chuck Low', 'Frank Dileo', 'Henny Youngman', 'Gina Mastrogiacomo', 'Catherine Scorsese', 'Charles Scorsese', 'Suzanne Shepherd', 'Debi Mazar', 'Margo Winkler'], 'directors': ['Martin Scorsese'], 'writers': ['Nicholas Pileggi', 'Martin Scorsese']})
# (18, {'rank': 18, 'name': "One Flew Over the Cuckoo's Nest", 'year': 1975, 'rating': 8.7, 'genre': ['Drama'], 'certificate': '18+', 'run_time': '2h 13m', 'tagline': "If he's crazy, what does that make you?", 'budget': '3000000', 'box_office': '109114817', 'casts': ['Jack Nicholson', 'Louise Fletcher', 'Michael Berryman', 'Peter Brocco', 'Dean R. Brooks', 'Alonzo Brown', 'Scatman Crothers', 'Mwako Cumbuka', 'Danny Devito', 'William Duell', 'Josip Elic', 'Lan Fendors', 'Nathan George', 'Ken Kenny', 'Mel Lambert', 'Sydney Lassick', 'Kay Lee', 'Christopher Lloyd'], 'directors': ['Milos Forman'], 'writers': ['Lawrence Hauben', 'Bo Goldman', 'Ken Kesey']})
# (19, {'rank': 19, 'name': 'Se7en', 'year': 1995, 'rating': 8.6, 'genre': ['Crime', 'Drama', 'Mystery'], 'certificate': 'R', 'run_time': '2h 7m', 'tagline': 'Long is the way, and hard, that out of hell leads up to light.', 'budget': '33000000', 'box_office': '327333559', 'casts': ['Morgan Freeman', 'Brad Pitt', 'Kevin Spacey', 'Andrew Kevin Walker', 'Daniel Zacapa', 'Gwyneth Paltrow', 'John Cassini', 'Bob Mack', 'Peter Crombie', 'Reg E. Cathey', 'R. Lee Ermey', 'George Christy', 'Endre Hules', 'Hawthorne James', 'William Davidson', 'Bob Collins', 'Jimmy Dale Hartsell', 'Richard Roundtree'], 'directors': ['David Fincher'], 'writers': ['Andrew Kevin Walker']})
# (20, {'rank': 20, 'name': 'Seven Samurai', 'year': 1954, 'rating': 8.6, 'genre': ['Action', 'Drama'], 'certificate': 'Not Rated', 'run_time': '3h 27m', 'tagline': 'Will Take Its Place With the Seven Greatest Films of All Time!', 'budget': '125000000', 'box_office': '346258', 'casts': ['Toshirô Mifune', 'Takashi Shimura', 'Keiko Tsushima', 'Yukiko Shimazaki', 'Kamatari Fujiwara', 'Daisuke Katô', 'Isao Kimura', 'Minoru Chiaki', 'Seiji Miyaguchi', 'Yoshio Kosugi', 'Bokuzen Hidari', 'Yoshio Inaba', 'Yoshio Tsuchiya', 'Kokuten Kôdô', 'Eijirô Tôno', 'Kichijirô Ueda', 'Jun Tatara', 'Atsushi Watanabe'], 'directors': ['Akira Kurosawa'], 'writers': ['Akira Kurosawa', 'Shinobu Hashimoto', 'Hideo Oguni']})
# (21, {'rank': 21, 'name': "It's a Wonderful Life", 'year': 1946, 'rating': 8.6, 'genre': ['Drama', 'Family', 'Fantasy'], 'certificate': 'PG', 'run_time': '2h 10m', 'tagline': 'Frank Capra\'s..."It\'s a Wonderful Life".', 'budget': '3180000', 'box_office': '8574081', 'casts': ['James Stewart', 'Donna Reed', 'Lionel Barrymore', 'Thomas Mitchell', 'Henry Travers', 'Beulah Bondi', 'Frank Faylen', 'Ward Bond', 'Gloria Grahame', 'H.B. Warner', 'Frank Albertson', 'Todd Karns', 'Samuel S. Hinds', 'Mary Treen', 'Virginia Patton', 'Charles Williams', 'Sarah Edwards', 'William Edmunds'], 'directors': ['Frank Capra'], 'writers': ['Frances Goodrich', 'Albert Hackett', 'Frank Capra']})
# (22, {'rank': 22, 'name': 'The Silence of the Lambs', 'year': 1991, 'rating': 8.6, 'genre': ['Crime', 'Drama', 'Thriller'], 'certificate': 'R', 'run_time': '1h 58m', 'tagline': 'Dr. Hannibal Lecter. Brilliant. Cunning. Psychotic. In his mind lies the clue to a ruthless killer. - Clarice Starling, FBI. Brilliant. Vulnerable. Alone. She must trust him to stop the killer.', 'budget': '19000000', 'box_office': '272742922', 'casts': ['Jodie Foster', 'Anthony Hopkins', 'Lawrence A. Bonney', 'Kasi Lemmons', 'Lawrence T. Wrentz', 'Scott Glenn', 'Anthony Heald', 'Frankie Faison', 'Don Brockett', 'Frank Seals Jr.', 'Stuart Rudin', 'Maria Skorobogatov', 'Jeffrie Lane', 'Leib Lensky', "George 'Red' Schwartz", 'Jim Roche', 'Brooke Smith', 'Ted Levine'], 'directors': ['Jonathan Demme'], 'writers': ['Thomas Harris', 'Ted Tally']})
# (23, {'rank': 23, 'name': 'City of God', 'year': 2002, 'rating': 8.6, 'genre': ['Crime', 'Drama'], 'certificate': 'R', 'run_time': '2h 10m', 'tagline': 'If you run, the beast will get you. If you stay, the beast will eat you', 'budget': '$3300000', 'box_office': '30680793', 'casts': ['Alexandre Rodrigues', 'Leandro Firmino', 'Matheus Nachtergaele', 'Phellipe Haagensen', 'Douglas Silva', 'Jonathan Haagensen', 'Seu Jorge', 'Jefechander Suplino', 'Alice Braga', 'Emerson Gomes', 'Edson Oliveira', 'Michel Gomes', 'Roberta Rodrigues', 'Luis Otávio', 'Kiko Marques', 'Gustavo Engrácia', 'Darlan Cunha', 'Robson Rocha'], 'directors': ['Fernando Meirelles', 'Kátia Lund(Co-Director)'], 'writers': ['Paulo Lins', 'Bráulio Mantovani']})
# (24, {'rank': 24, 'name': 'Saving Private Ryan', 'year': 1998, 'rating': 8.6, 'genre': ['Drama', 'War'], 'certificate': 'R', 'run_time': '2h 49m', 'tagline': 'In the Last Great Invasion of the Last Great War, The Greatest Danger for Eight Men was Saving... One.', 'budget': '70000000', 'box_office': '482349603', 'casts': ['Tom Hanks', 'Matt Damon', 'Tom Sizemore', 'Edward Burns', 'Barry Pepper', 'Adam Goldberg', 'Vin Diesel', 'Giovanni Ribisi', 'Jeremy Davies', 'Ted Danson', 'Paul Giamatti', 'Dennis Farina', 'Joerg Stadler', 'Max Martini', 'Dylan Bruno', 'Daniel Cerqueira', 'Demetri Goritsas', 'Ian Porter'], 'directors': ['Steven Spielberg'], 'writers': ['Robert Rodat']})
# (25, {'rank': 25, 'name': 'Interstellar', 'year': 2014, 'rating': 8.6, 'genre': ['Adventure', 'Drama', 'Sci-Fi'], 'certificate': 'PG-13', 'run_time': '2h 49m', 'tagline': 'Mankind was born on Earth. It was never meant to die here.', 'budget': '165000000', 'box_office': '773867216', 'casts': ['Matthew Mcconaughey', 'Anne Hathaway', 'Jessica Chastain', 'Mackenzie Foy', 'Ellen Burstyn', 'John Lithgow', 'Timothée Chalamet', 'David Oyelowo', 'Collette Wolfe', 'Francis X. Mccarthy', 'Bill Irwin', 'Andrew Borba', 'Wes Bentley', 'William Devane', 'Michael Caine', 'David Gyasi', 'Josh Stewart', 'Casey Affleck'], 'directors': ['Christopher Nolan'], 'writers': ['Jonathan Nolan', 'Christopher Nolan']})
# (26, {'rank': 26, 'name': 'Life Is Beautiful', 'year': 1997, 'rating': 8.6, 'genre': ['Comedy', 'Drama', 'Romance'], 'certificate': 'PG-13', 'run_time': '1h 56m', 'tagline': 'An unforgettable fable that proves love, family and imagination conquer all. (Canadian one sheet)', 'budget': '20000000', 'box_office': '230098753', 'casts': ['Roberto Benigni', 'Nicoletta Braschi', 'Giorgio Cantarini', 'Giustino Durano', 'Sergio Bini Bustric', 'Marisa Paredes', 'Horst Buchholz', 'Lidia Alfonsi', 'Giuliana Lojodice', 'Amerigo Fontani', 'Pietro De Silva', 'Francesco Guzzo', 'Raffaella Lebboroni', 'Claudio Alfonsi', 'Gil Baroni', 'Massimo Bianchi', 'Jürgen Bohn', 'Verena Buratti'], 'directors': ['Roberto Benigni'], 'writers': ['Vincenzo Cerami', 'Roberto Benigni']})
# (27, {'rank': 27, 'name': 'The Green Mile', 'year': 1999, 'rating': 8.6, 'genre': ['Crime', 'Drama', 'Fantasy'], 'certificate': 'R', 'run_time': '3h 9m', 'tagline': 'Miracles do happen.', 'budget': '60000000', 'box_office': '286801374', 'casts': ['Tom Hanks', 'Michael Clarke Duncan', 'David Morse', 'Bonnie Hunt', 'James Cromwell', 'Michael Jeter', 'Graham Greene', 'Doug Hutchison', 'Sam Rockwell', 'Barry Pepper', 'Jeffrey Demunn', 'Patricia Clarkson', 'Harry Dean Stanton', 'Dabbs Greer', 'Eve Brent', 'William Sadler', 'Mack Miles', 'Rai Tasco'], 'directors': ['Frank Darabont'], 'writers': ['Stephen King', 'Frank Darabont']})
# (28, {'rank': 28, 'name': 'Star Wars: Episode IV - A New Hope', 'year': 1977, 'rating': 8.6, 'genre': ['Action', 'Adventure', 'Fantasy'], 'certificate': 'PG', 'run_time': '2h 1m', 'tagline': "It's Back! The Force will be with you for three weeks only. (1979 Reissue Poster)", 'budget': '11000000', 'box_office': '775398007', 'casts': ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher', 'Alec Guinness', 'Peter Cushing', 'Anthony Daniels', 'Kenny Baker', 'Peter Mayhew', 'David Prowse', 'Phil Brown', 'Shelagh Fraser', 'Jack Purvis', 'Alex Mccrindle', 'Eddie Byrne', 'Drewe Henley', 'Denis Lawson', 'Garrick Hagon', 'Jack Klaff'], 'directors': ['George Lucas'], 'writers': ['George Lucas']})
# (29, {'rank': 29, 'name': 'Terminator 2: Judgment Day', 'year': 1991, 'rating': 8.6, 'genre': ['Action', 'Sci-Fi'], 'certificate': 'R', 'run_time': '2h 17m', 'tagline': "It's nothing personal.", 'budget': '102000000', 'box_office': '520881154', 'casts': ['Arnold Schwarzenegger', 'Linda Hamilton', 'Edward Furlong', 'Robert Patrick', 'Earl Boen', 'Joe Morton', 'S. Epatha Merkerson', 'Castulo Guerra', 'Danny Cooksey', 'Jenette Goldstein', 'Xander Berkeley', 'Leslie Hamilton Gearren', 'Ken Gibbel', 'Robert Winley', 'Peter Schrum', 'Shane Wilder', 'Michael Edwards', 'Jared Lounsbery'], 'directors': ['James Cameron'], 'writers': ['James Cameron', 'William Wisher']})
# (30, {'rank': 30, 'name': 'Back to the Future', 'year': 1985, 'rating': 8.5, 'genre': ['Adventure', 'Comedy', 'Sci-Fi'], 'certificate': 'PG', 'run_time': '1h 56m', 'tagline': "He's the only kid ever to get into trouble before he was born. [UK]", 'budget': '19000000', 'box_office': '383336762', 'casts': ['Michael J. Fox', 'Christopher Lloyd', 'Lea Thompson', 'Crispin Glover', 'Tom Wilson', 'Claudia Wells', 'Marc Mcclure', 'Wendie Jo Sperber', 'George Dicenzo', 'Frances Lee Mccain', 'James Tolkan', 'J.J. Cohen', 'Casey Siemaszko', 'Billy Zane', 'Harry Waters Jr.', 'Donald Fullilove', 'Lisa Freeman', 'Cristen Kauffman'], 'directors': ['Robert Zemeckis'], 'writers': ['Robert Zemeckis', 'Bob Gale']})
# (31, {'rank': 31, 'name': 'Spirited Away', 'year': 2001, 'rating': 8.6, 'genre': ['Animation', 'Adventure', 'Family'], 'certificate': 'PG', 'run_time': '2h 5m', 'tagline': 'The tunnel led Chihiro to a mysterious town.', 'budget': '19000000', 'box_office': '355822319', 'casts': ['Daveigh Chase', 'Suzanne Pleshette', 'Miyu Irino', 'Rumi Hiiragi', 'Mari Natsuki', 'Takashi Naitô', 'Yasuko Sawaguchi', 'Tatsuya Gashûin', 'Ryûnosuke Kamiki', 'Yumi Tamai', 'Yô Ôizumi', 'Koba Hayashi', 'Tsunehiko Kamijô', 'Takehiko Ono', 'Bunta Sugawara', 'Shigeru Wakita', 'Shirô Saitô', 'Michiko Yamamoto'], 'directors': ['Hayao Miyazaki'], 'writers': ['Hayao Miyazaki']})
# (32, {'rank': 32, 'name': 'The Pianist', 'year': 2002, 'rating': 8.5, 'genre': ['Biography', 'Drama', 'Music'], 'certificate': 'R', 'run_time': '2h 30m', 'tagline': 'Music was his passion. Survival was his masterpiece.', 'budget': '35000000', 'box_office': '120072577', 'casts': ['Adrien Brody', 'Thomas Kretschmann', 'Frank Finlay', 'Emilia Fox', 'Michal Zebrowski', 'Ed Stoppard', 'Maureen Lipman', 'Jessica Kate Meyer', 'Julia Rayner', 'Wanja Mues', 'Richard Ridings', 'Nomi Sharron', 'Anthony Milner', 'Lucy Skeaping', 'Roddy Skeaping', 'Ben Harlan', 'Thomas Lawinky', 'Joachim Paul Assböck'], 'directors': ['Roman Polanski'], 'writers': ['Ronald Harwood', 'Wladyslaw Szpilman']})
# (33, {'rank': 33, 'name': 'Psycho', 'year': 1960, 'rating': 8.5, 'genre': ['Horror', 'Mystery', 'Thriller'], 'certificate': 'R', 'run_time': '1h 49m', 'tagline': "The picture you MUST see from the beginning... Or not at all!... For no one will be seated after the start of... Alfred Hitchcock's greatest shocker Psycho.", 'budget': '806947', 'box_office': '32052925', 'casts': ['Anthony Perkins', 'Janet Leigh', 'Vera Miles', 'John Gavin', 'Martin Balsam', 'John Mcintire', 'Simon Oakland', 'Frank Albertson', 'Patricia Hitchcock', 'Vaughn Taylor', 'Lurene Tuttle', 'John Anderson', 'Mort Mills', 'Fletcher Allen', 'Walter Bacon', 'Prudence Beers', 'Kit Carson', 'Francis De Sales'], 'directors': ['Alfred Hitchcock'], 'writers': ['Joseph Stefano', 'Robert Bloch']})
# (34, {'rank': 34, 'name': 'Parasite', 'year': 2019, 'rating': 8.5, 'genre': ['Drama', 'Thriller'], 'certificate': 'R', 'run_time': '2h 12m', 'tagline': 'Misplaced familyhood (Australia/New Zealand/Singapore)', 'budget': '11400000', 'box_office': '262676096', 'casts': ['Song Kang-Ho', 'Lee Sun-Kyun', 'Cho Yeo-Jeong', 'Choi Woo-Sik', 'Park So-Dam', 'Lee Jeong-Eun', 'Jang Hye-Jin', 'Park Myeong-Hoon', 'Jung Ji-So', 'Jung Hyun-Jun', 'Park Keun-Rok', 'Jung Yi-Seo', 'Jo Jae-Myeong', 'Jung Ik-Han', 'Kim Kyu-Baek', 'Hwang In-Kyung', 'Ahn Seong-Bong', 'Kim Jin-Hyung'], 'directors': ['Bong Joon Ho'], 'writers': ['Bong Joon Ho', 'Han Jin-Won']})
# (35, {'rank': 35, 'name': 'Léon: The Professional', 'year': 1994, 'rating': 8.5, 'genre': ['Action', 'Crime', 'Drama'], 'certificate': 'R', 'run_time': '1h 50m', 'tagline': 'If you want the job done right, hire a professional.', 'budget': 'RF\xa0115000000', 'box_office': '19569225', 'casts': ['Jean Reno', 'Gary Oldman', 'Natalie Portman', 'Danny Aiello', 'Peter Appel', 'Willi One Blood', 'Don Creech', 'Keith A. Glascoe', 'Randolph Scott', 'Michael Badalucco', 'Ellen Greene', 'Elizabeth Regen', 'Carl J. Matusovich', 'Frank Senger', 'Lucius Wyatt Cherokee', 'Eric Challier', 'Luc Bernard', 'Maïwenn'], 'directors': ['Luc Besson'], 'writers': ['Luc Besson']})
# (36, {'rank': 36, 'name': 'The Lion King', 'year': 1994, 'rating': 8.5, 'genre': ['Animation', 'Adventure', 'Drama'], 'certificate': 'G', 'run_time': '1h 28m', 'tagline': 'See it for the first time ever in 3D (2011 3D re-release)', 'budget': '45000000', 'box_office': '968511805', 'casts': ['Matthew Broderick', 'Jeremy Irons', 'James Earl Jones', 'Whoopi Goldberg', 'Rowan Atkinson', 'Niketa Calame-Harris', 'Jim Cummings', 'Robert Guillaume', 'Moira Kelly', 'Nathan Lane', 'Zoe Leader', 'Cheech Marin', 'Ernie Sabella', 'Madge Sinclair', 'Jonathan Taylor Thomas', 'Frank Welker', 'Cathy Cavadini', 'Judi M. Durand'], 'directors': ['Roger Allers', 'Rob Minkoff'], 'writers': ['Irene Mecchi', 'Jonathan Roberts', 'Linda Woolverton']})
# (37, {'rank': 37, 'name': 'Gladiator', 'year': 2000, 'rating': 8.5, 'genre': ['Action', 'Adventure', 'Drama'], 'certificate': 'R', 'run_time': '2h 35m', 'tagline': 'Father of a murdered son, husband to a murdered wife and I shall have my vengeance in this life or the next', 'budget': '103000000', 'box_office': '503162313', 'casts': ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen', 'Oliver Reed', 'Richard Harris', 'Derek Jacobi', 'Djimon Hounsou', 'David Schofield', 'John Shrapnel', 'Tomas Arana', 'Ralf Moeller', 'Spencer Treat Clark', 'David Hemmings', 'Tommy Flanagan', 'Sven-Ole Thorsen', 'Omid Djalili', 'Nicholas Mcgaughey', 'Chris Kell'], 'directors': ['Ridley Scott'], 'writers': ['David Franzoni', 'John Logan', 'William Nicholson']})
# (38, {'rank': 38, 'name': 'American History X', 'year': 1998, 'rating': 8.5, 'genre': ['Crime', 'Drama'], 'certificate': 'R', 'run_time': '1h 59m', 'tagline': 'His father taught him to hate. His friends taught him rage. His enemies gave him hope.', 'budget': '20000000', 'box_office': '23875127', 'casts': ['Edward Norton', 'Edward Furlong', "Beverly D'Angelo", 'Jennifer Lien', 'Ethan Suplee', 'Fairuza Balk', 'Avery Brooks', 'Elliott Gould', 'Stacy Keach', 'William Russ', 'Guy Torry', 'Joe Cortese', 'Jason Bose Smith', 'Antonio David Lyons', 'Alex Sol', 'Keram Malicki-Sánchez', 'Giuseppe Andrews', 'Michelle Christine White'], 'directors': ['Tony Kaye'], 'writers': ['David Mckenna']})
# (39, {'rank': 39, 'name': 'The Departed', 'year': 2006, 'rating': 8.5, 'genre': ['Crime', 'Drama', 'Thriller'], 'certificate': 'R', 'run_time': '2h 31m', 'tagline': 'Lies. Betrayal. Sacrifice. How far will you take it?', 'budget': '90000000', 'box_office': '291480452', 'casts': ['Leonardo Dicaprio', 'Matt Damon', 'Jack Nicholson', 'Mark Wahlberg', 'Martin Sheen', 'Ray Winstone', 'Vera Farmiga', 'Anthony Anderson', 'Alec Baldwin', 'Kevin Corrigan', 'James Badge Dale', "David O'Hara", 'Mark Rolston', 'Robert Wahlberg', 'Kristen Dalton', 'Thomas B. Duffy', 'Richard Hughes', 'J.C. Mackenzie'], 'directors': ['Martin Scorsese'], 'writers': ['William Monahan', 'Alan Mak', 'Felix Chong']})
# (40, {'rank': 40, 'name': 'The Usual Suspects', 'year': 1995, 'rating': 8.5, 'genre': ['Crime', 'Drama', 'Mystery'], 'certificate': 'R', 'run_time': '1h 46m', 'tagline': "The greatest trick the devil ever pulled was to convince the world he didn't exist", 'budget': '6000000', 'box_office': '23341568', 'casts': ['Kevin Spacey', 'Gabriel Byrne', 'Chazz Palminteri', 'Stephen Baldwin', 'Benicio Del Toro', 'Kevin Pollak', 'Pete Postlethwaite', 'Suzy Amis', 'Giancarlo Esposito', 'Dan Hedaya', 'Paul Bartel', 'Carl Bressler', 'Phillipe Simon', 'Jack Shearer', 'Christine Estabrook', 'Clark Gregg', 'Morgan Hunter', 'Ken Daly'], 'directors': ['Bryan Singer'], 'writers': ['Christopher Mcquarrie']})
# (41, {'rank': 41, 'name': 'The Prestige', 'year': 2006, 'rating': 8.5, 'genre': ['Drama', 'Mystery', 'Sci-Fi'], 'certificate': 'PG-13', 'run_time': '2h 10m', 'tagline': 'A Friendship That Became a Rivalry.', 'budget': '40000000', 'box_office': '109676311', 'casts': ['Christian Bale', 'Hugh Jackman', 'Scarlett Johansson', 'Michael Caine', 'Piper Perabo', 'Rebecca Hall', 'Samantha Mahurin', 'David Bowie', 'Andy Serkis', 'Daniel Davis', 'Jim Piddock', 'Christopher Neame', 'Mark Ryan', 'Roger Rees', 'Jamie Harris', 'Monty Stuart', 'Ron Perkins', 'Ricky Jay'], 'directors': ['Christopher Nolan'], 'writers': ['Jonathan Nolan', 'Christopher Nolan', 'Christopher Priest']})
# (42, {'rank': 42, 'name': 'Whiplash', 'year': 2014, 'rating': 8.5, 'genre': ['Drama', 'Music'], 'certificate': 'R', 'run_time': '1h 46m', 'tagline': 'The road to greatness can take you to the edge', 'budget': '3300000', 'box_office': '49396747', 'casts': ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist', 'Paul Reiser', 'Austin Stowell', 'Nate Lang', 'Chris Mulkey', 'Damon Gupton', 'Suanne Spoke', 'Max Kasch', 'Charlie Ian', 'Jayson Blair', 'Kofi Siriboe', 'Kavita Patil', 'C.J. Vana', 'Tarik Lowe', 'Tyler Kimball', 'Rogelio Douglas Jr.'], 'directors': ['Damien Chazelle'], 'writers': ['Damien Chazelle']})
# (43, {'rank': 43, 'name': 'Casablanca', 'year': 1942, 'rating': 8.5, 'genre': ['Drama', 'Romance', 'War'], 'certificate': 'PG', 'run_time': '1h 42m', 'tagline': 'Where Love Cuts as Deep as a Dagger!', 'budget': '950000', 'box_office': '4626532', 'casts': ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid', 'Claude Rains', 'Conrad Veidt', 'Sydney Greenstreet', 'Peter Lorre', 'S.Z. Sakall', 'Madeleine Lebeau', 'Dooley Wilson', 'Joy Page', 'John Qualen', 'Leonid Kinskey', 'Curt Bois', 'Abdullah Abbas', 'Enrique Acosta', 'Ed Agresti', 'Arnet Amos'], 'directors': ['Michael Curtiz'], 'writers': ['Julius J. Epstein', 'Philip G. Epstein', 'Howard Koch']})
# (44, {'rank': 44, 'name': 'Grave of the Fireflies', 'year': 1988, 'rating': 8.5, 'genre': ['Animation', 'Drama', 'War'], 'certificate': 'Not Rated', 'run_time': '1h 29m', 'tagline': 'imationDramaWar', 'budget': '3700000', 'box_office': '516962', 'casts': ['Tsutomu Tatsumi', 'Ayano Shiraishi', 'Akemi Yamaguchi', 'Yoshiko Shinohara', 'Kôzô Hashida', 'Masayo Sakai', 'Kazumi Nozaki', 'Yoshio Matsuoka', 'Masahiro Kanetake', 'Kiyoshi Yanagawa', 'Hajime Maki', 'Atsuo Omote', 'Teruhisa Harita', 'Hiroshi Tanaka', 'Michio Denpô', 'Shirô Tamaki', 'Tadashi Nakamura', 'Mika Sekita'], 'directors': ['Isao Takahata'], 'writers': ['Akiyuki Nosaka', 'Isao Takahata']})
# (45, {'rank': 45, 'name': 'Harakiri', 'year': 1962, 'rating': 8.6, 'genre': ['Action', 'Drama', 'Mystery'], 'certificate': 'Not Rated', 'run_time': '2h 13m', 'tagline': 'The World Has Never Understood Why the Japanese Prefer Death to Dishonor! This Samurai Picture Provides The Answer!!', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima Iwashita', 'Tetsurô Tanba', 'Masao Mishima', 'Ichirô Nakatani', 'Kei Satô', 'Yoshio Inaba', 'Hisashi Igawa', 'Tôru Takeuchi', 'Yoshirô Aoki', 'Tatsuo Matsumura', 'Akiji Kobayashi', 'Kôichi Hayashi', 'Ryûtarô Gomi', 'Jô Azumi', 'Nakajirô Tomita', 'Shichisaburô Amatsu'], 'directors': ['Masaki Kobayashi'], 'writers': ['Yasuhiko Takiguchi', 'Shinobu Hashimoto']})
# (46, {'rank': 46, 'name': 'The Intouchables', 'year': 2011, 'rating': 8.5, 'genre': ['Biography', 'Comedy', 'Drama'], 'certificate': 'R', 'run_time': '1h 52m', 'tagline': "Sometimes you have to reach into someone else's world to find out what's missing in your own.", 'budget': '9500000', 'box_office': '426588510', 'casts': ['François Cluzet', 'Omar Sy', 'Anne Le Ny', 'Audrey Fleurot', 'Joséphine De Meaux', 'Clotilde Mollet', 'Alba Gaïa Bellugi', 'Cyril Mendy', 'Salimata Kamate', 'Absa Diatou Toure', 'Grégoire Oestermann', 'Dominique Daguier', 'François Caron', 'Christian Ameri', 'Thomas Solivérès', 'Dorothée Brière', 'Marie-Laure Descoureaux', 'Émilie Caen'], 'directors': ['Olivier Nakache', 'Éric Toledano'], 'writers': ['Olivier Nakache', 'Éric Toledano', 'Philippe Pozzo Di Borgo']})
# (47, {'rank': 47, 'name': 'Modern Times', 'year': 1936, 'rating': 8.5, 'genre': ['Comedy', 'Drama', 'Romance'], 'certificate': 'G', 'run_time': '1h 27m', 'tagline': 'He stands alone as the greatest entertainer of modern times! No one on earth can make you laugh as heartily or touch your heart as deeply...the whole world laughs, cries and thrills to his priceless genius!', 'budget': '1500000', 'box_office': '463618', 'casts': ['Charles Chaplin', 'Paulette Goddard', 'Henry Bergman', 'Tiny Sandford', 'Chester Conklin', 'Hank Mann', 'Stanley Blystone', 'Al Ernest Garcia', 'Richard Alexander', 'Cecil Reynolds', 'Mira Mckinney', 'Murdock Macquarrie', 'Wilfred Lucas', 'Edward Lesaint', 'Fred Malatesta', 'Sammy Stein', 'Juana Sutton', 'Ted Oliver'], 'directors': ['Charles Chaplin'], 'writers': ['Charles Chaplin']})
# (48, {'rank': 48, 'name': 'Once Upon a Time in the West', 'year': 1968, 'rating': 8.5, 'genre': ['Western'], 'certificate': 'PG-13', 'run_time': '2h 45m', 'tagline': 'There were three men in her life. One knew her past. One wanted her land. One wanted revenge.', 'budget': '5000000', 'box_office': '5435024', 'casts': ['Henry Fonda', 'Charles Bronson', 'Claudia Cardinale', 'Jason Robards', 'Gabriele Ferzetti', 'Paolo Stoppa', 'Woody Strode', 'Jack Elam', 'Keenan Wynn', 'Frank Wolff', 'Lionel Stander', 'Livio Andronico', 'Salvatore Basile', 'Aldo Berti', 'Joseph Bradley', 'Frank Braña', 'Marilù Carteny', 'Saturno Cerra'], 'directors': ['Sergio Leone'], 'writers': ['Sergio Donati', 'Sergio Leone', 'Dario Argento']})
# (49, {'rank': 49, 'name': 'Rear Window', 'year': 1954, 'rating': 8.5, 'genre': ['Mystery', 'Thriller'], 'certificate': 'PG', 'run_time': '1h 52m', 'tagline': 'The Essential Hitchcock', 'budget': '1000000', 'box_office': '37034579', 'casts': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter', 'Raymond Burr', 'Judith Evelyn', 'Ross Bagdasarian', 'Georgine Darcy', 'Sara Berner', 'Frank Cady', 'Jesslyn Fax', 'Rand Harper', 'Irene Winston', 'Havis Davenport', 'Jerry Antes', 'Barbara Bailey', 'Benny Bartlett', 'Nick Borgani'], 'directors': ['Alfred Hitchcock'], 'writers': ['John Michael Hayes', 'Cornell Woolrich']})
# (50, {'rank': 50, 'name': 'Cinema Paradiso', 'year': 1988, 'rating': 8.5, 'genre': ['Drama', 'Romance'], 'certificate': 'PG', 'run_time': '2h 35m', 'tagline': 'A celebration of youth, friendship, and the everlasting magic of the movies.', 'budget': '5000000', 'box_office': '13019063', 'casts': ['Philippe Noiret', 'Enzo Cannavale', 'Antonella Attili', 'Isa Danieli', 'Leo Gullotta', 'Marco Leonardi', 'Pupella Maggio', 'Agnese Nano', 'Leopoldo Trieste', 'Salvatore Cascio', 'Tano Cimarosa', 'Nicola Di Pinto', 'Roberta Lena', 'Nino Terzo', 'Jacques Perrin', 'Nellina Laganà', 'Turi Giuffrida', 'Mariella Lo Giudice'], 'directors': ['Giuseppe Tornatore'], 'writers': ['Giuseppe Tornatore', 'Vanna Paoli']})
# (51, {'rank': 51, 'name': 'Alien', 'year': 1979, 'rating': 8.5, 'genre': ['Horror', 'Sci-Fi'], 'certificate': 'R', 'run_time': '1h 57m', 'tagline': 'In space no one can hear you scream.', 'budget': '11000000', 'box_office': '106285522', 'casts': ['Sigourney Weaver', 'Tom Skerritt', 'John Hurt', 'Veronica Cartwright', 'Harry Dean Stanton', 'Ian Holm', 'Yaphet Kotto', 'Bolaji Badejo', 'Helen Horton', 'Eddie Powell'], 'directors': ['Ridley Scott'], 'writers': ["Dan O'Bannon", 'Ronald Shusett']})
# (52, {'rank': 52, 'name': 'City Lights', 'year': 1931, 'rating': 8.5, 'genre': ['Comedy', 'Drama', 'Romance'], 'certificate': 'G', 'run_time': '1h 27m', 'tagline': 'HE RETURNS -And the world rocks again with laughter. (Print Ad-Daily Examiner, ((Grafton, NSW)) 6 July 1931)', 'budget': '1500000', 'box_office': '50419', 'casts': ['Charles Chaplin', 'Virginia Cherrill', 'Florence Lee', 'Harry Myers', 'Al Ernest Garcia', 'Hank Mann', 'Johnny Aber', 'Jack Alexander', 'T.S. Alexander', 'Victor Alexander', 'Albert Austin', 'Harry Ayers', 'Eddie Baker', 'Henry Bergman', 'Edward Biby', 'Betty Blair', 'Buster Brodie', 'Jeanne Carpenter'], 'directors': ['Charles Chaplin'], 'writers': ['Charles Chaplin', 'Harry Carr', 'Harry Crocker']})
# (53, {'rank': 53, 'name': 'Apocalypse Now', 'year': 1979, 'rating': 8.5, 'genre': ['Drama', 'Mystery', 'War'], 'certificate': 'R', 'run_time': '2h 27m', 'tagline': 'The Horror. . . The Horror. . .', 'budget': '31500000', 'box_office': '104880868', 'casts': ['Martin Sheen', 'Marlon Brando', 'Robert Duvall', 'Frederic Forrest', 'Sam Bottoms', 'Laurence Fishburne', 'Albert Hall', 'Harrison Ford', 'Dennis Hopper', 'G.D. Spradlin', 'Jerry Ziesmer', 'Scott Glenn', 'Bo Byers', 'James Keane', 'Kerry Rossall', 'Ron Mcqueen', 'Tom Mason', 'Cynthia Wood'], 'directors': ['Francis Ford Coppola'], 'writers': ['John Milius', 'Francis Ford Coppola', 'Michael Herr']})
# (54, {'rank': 54, 'name': 'Memento', 'year': 2000, 'rating': 8.4, 'genre': ['Mystery', 'Thriller'], 'certificate': 'R', 'run_time': '1h 53m', 'tagline': 'Some memories are best forgotten', 'budget': '9000000', 'box_office': '40047078', 'casts': ['Guy Pearce', 'Carrie-Anne Moss', 'Joe Pantoliano', 'Mark Boone Junior', 'Russ Fega', 'Jorja Fox', 'Stephen Tobolowsky', 'Harriet Sansom Harris', 'Thomas Lennon', 'Callum Keith Rennie', 'Kimberly Campbell', 'Marianne Muellerleile', 'Larry Holden', 'Stephanie Searson', 'Buzz Visconti'], 'directors': ['Christopher Nolan'], 'writers': ['Christopher Nolan', 'Jonathan Nolan']})
# (55, {'rank': 55, 'name': 'Django Unchained', 'year': 2012, 'rating': 8.4, 'genre': ['Drama', 'Western'], 'certificate': 'R', 'run_time': '2h 45m', 'tagline': 'Life, liberty and the pursuit of vengeance.', 'budget': '100000000', 'box_office': '426074373', 'casts': ['Jamie Foxx', 'Christoph Waltz', 'Leonardo Dicaprio', 'Kerry Washington', 'Samuel L. Jackson', 'Walton Goggins', 'Dennis Christopher', 'James Remar', 'David Steen', 'Dana Gourrier', 'Nichole Galicia', 'Laura Cayouette', 'Ato Essandoh', 'Sammi Rotibi', 'Clay Donahue Fontenot', 'Escalante Lundy', 'Miriam F. Glover', 'Don Johnson'], 'directors': ['Quentin Tarantino'], 'writers': ['Quentin Tarantino']})
# (56, {'rank': 56, 'name': 'Indiana Jones and the Raiders of the Lost Ark', 'year': 1981, 'rating': 8.4, 'genre': ['Action', 'Adventure'], 'certificate': 'PG', 'run_time': '1h 55m', 'tagline': 'Indiana Jones - the new hero from the creators of JAWS and STAR WARS.', 'budget': '18000000', 'box_office': '389925971', 'casts': ['Harrison Ford', 'Karen Allen', 'Paul Freeman', 'John Rhys-Davies', 'Ronald Lacey', 'Denholm Elliott', 'Alfred Molina', 'Wolf Kahler', 'Anthony Higgins', 'Vic Tablian', 'Don Fellows', 'William Hootkins', 'Bill Reimbold', 'Fred Sorenson', 'Patrick Durkin', 'Matthew Scurfield', 'Malcolm Weaver', 'Sonny Caldinez'], 'directors': ['Steven Spielberg'], 'writers': ['Lawrence Kasdan', 'George Lucas', 'Philip Kaufman']})
# (57, {'rank': 57, 'name': 'WALL·E', 'year': 2008, 'rating': 8.4, 'genre': ['Animation', 'Adventure', 'Family'], 'certificate': 'G', 'run_time': '1h 38m', 'tagline': "After 700 years of doing what he was built for - he'll discover what he's meant for.", 'budget': '180000000', 'box_office': '521311890', 'casts': ['Ben Burtt', 'Elissa Knight', 'Jeff Garlin', 'Fred Willard', 'Macintalk', 'John Ratzenberger', 'Kathy Najimy', 'Sigourney Weaver', 'Karleen Griffin', 'Kim Kopf', 'Niki Mcelroy', 'Garrett Palmer', 'Jessica Skelton', 'Kai Steel Smith', 'Michael Toy'], 'directors': ['Andrew Stanton'], 'writers': ['Andrew Stanton', 'Pete Docter', 'Jim Reardon']})
# (58, {'rank': 58, 'name': 'The Lives of Others', 'year': 2006, 'rating': 8.4, 'genre': ['Drama', 'Mystery', 'Thriller'], 'certificate': 'R', 'run_time': '2h 17m', 'tagline': "Before the Fall of the Berlin Wall, East Germany's Secret Police Listened to Your Secrets", 'budget': '2000000', 'box_office': '77356942', 'casts': ['Ulrich Mühe', 'Martina Gedeck', 'Sebastian Koch', 'Ulrich Tukur', 'Thomas Thieme', 'Hans-Uwe Bauer', 'Volkmar Kleinert', 'Matthias Brenner', 'Charly Hübner', 'Herbert Knaup', 'Bastian Trost', 'Marie Gruber', 'Volker Michalowski', 'Werner Daehn', 'Martin Brambach', 'Hubertus Hartmann', 'Thomas Arnold', 'Hinnerk Schönemann'], 'directors': ['Florian Henckel Von Donnersmarck'], 'writers': ['Florian Henckel Von Donnersmarck']})
# (59, {'rank': 59, 'name': 'Sunset Blvd.', 'year': 1950, 'rating': 8.4, 'genre': ['Drama', 'Film-Noir'], 'certificate': 'Passed', 'run_time': '1h 50m', 'tagline': 'A Hollywood Story', 'budget': '1752000', 'box_office': '300073', 'casts': ['William Holden', 'Gloria Swanson', 'Erich Von Stroheim', 'Nancy Olson', 'Fred Clark', 'Lloyd Gough', 'Jack Webb', 'Franklyn Farnum', 'Larry J. Blake', 'Charles Dayton', 'Cecil B. Demille', 'Hedda Hopper', 'Buster Keaton', 'Anna Q. Nilsson', 'H.B. Warner', 'Ray Evans', 'Jay Livingston', 'Fred Aldrich'], 'directors': ['Billy Wilder'], 'writers': ['Charles Brackett', 'Billy Wilder', 'D.M. Marshman Jr.']})
# (60, {'rank': 60, 'name': 'Paths of Glory', 'year': 1957, 'rating': 8.4, 'genre': ['Drama', 'War'], 'certificate': 'Approved', 'run_time': '1h 28m', 'tagline': 'Never has the screen thrust so deeply into the guts of war!', 'budget': '935000', 'box_office': '5252', 'casts': ['Kirk Douglas', 'Ralph Meeker', 'Adolphe Menjou', 'George Macready', 'Wayne Morris', 'Richard Anderson', 'Joe Turkel', 'Christiane Kubrick', 'Jerry Hausner', 'Peter Capell', 'Emile Meyer', 'Bert Freed', 'Kem Dibbs', 'Timothy Carey', 'Fred Bell', 'John Stein', 'Harold Benedict', 'Leon Briggs'], 'directors': ['Stanley Kubrick'], 'writers': ['Stanley Kubrick', 'Calder Willingham', 'Jim Thompson']})
# (61, {'rank': 61, 'name': 'The Shining', 'year': 1980, 'rating': 8.4, 'genre': ['Drama', 'Horror'], 'certificate': 'R', 'run_time': '2h 26m', 'tagline': 'Iconic terror from the No 1 bestselling writer.', 'budget': '19000000', 'box_office': '47335804', 'casts': ['Jack Nicholson', 'Shelley Duvall', 'Danny Lloyd', 'Scatman Crothers', 'Barry Nelson', 'Philip Stone', 'Joe Turkel', 'Anne Jackson', 'Tony Burton', 'Lia Beldam', 'Billie Gibson', 'Barry Dennen', 'David Baxt', 'Manning Redwood', 'Lisa Burns', 'Louise Burns', 'Robin Pappas', 'Alison Coleridge'], 'directors': ['Stanley Kubrick'], 'writers': ['Stephen King', 'Stanley Kubrick', 'Diane Johnson']})
# (62, {'rank': 62, 'name': 'The Great Dictator', 'year': 1940, 'rating': 8.4, 'genre': ['Comedy', 'Drama', 'War'], 'certificate': 'G', 'run_time': '2h 5m', 'tagline': 'The Comedy Masterpiece!', 'budget': '2000000', 'box_office': '970263', 'casts': ['Charles Chaplin', 'Paulette Goddard', 'Jack Oakie', 'Reginald Gardiner', 'Henry Daniell', 'Billy Gilbert', 'Grace Hayle', 'Carter Dehaven', 'Maurice Moscovitch', 'Emma Dunn', 'Bernard Gorcey', 'Paul Weigel', 'Chester Conklin', 'Esther Michelson', 'Hank Mann', 'Florence Wright', 'Eddie Gribbon', 'Rudolph Anders'], 'directors': ['Charles Chaplin'], 'writers': ['Charles Chaplin']})
# (63, {'rank': 63, 'name': 'Avengers: Infinity War', 'year': 2018, 'rating': 8.4, 'genre': ['Action', 'Adventure', 'Sci-Fi'], 'certificate': 'PG-13', 'run_time': '2h 29m', 'tagline': 'An entire universe. Once and for all.', 'budget': '321000000', 'box_office': '2052415039', 'casts': ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Chris Evans', 'Scarlett Johansson', 'Don Cheadle', 'Benedict Cumberbatch', 'Tom Holland', 'Chadwick Boseman', 'Zoe Saldana', 'Karen Gillan', 'Tom Hiddleston', 'Paul Bettany', 'Elizabeth Olsen', 'Anthony Mackie', 'Sebastian Stan', 'Idris Elba', 'Danai Gurira'], 'directors': ['Anthony Russo', 'Joe Russo'], 'writers': ['Christopher Markus', 'Stephen Mcfeely', 'Stan Lee']})
# (64, {'rank': 64, 'name': 'Witness for the Prosecution', 'year': 1957, 'rating': 8.4, 'genre': ['Crime', 'Drama', 'Mystery'], 'certificate': 'Approved', 'run_time': '1h 56m', 'tagline': 'The most electrifying entertainment of our time!', 'budget': '3000000', 'box_office': '7693', 'casts': ['Tyrone Power', 'Marlene Dietrich', 'Charles Laughton', 'Elsa Lanchester', 'John Williams', 'Henry Daniell', 'Ian Wolfe', 'Torin Thatcher', 'Norma Varden', "Una O'Connor", 'Francis Compton', 'Philip Tonge', 'Ruta Lee', 'Patrick Aherne', 'Don Ames', 'Walter Bacon', 'Eddie Baker', 'Benjie Bancroft'], 'directors': ['Billy Wilder'], 'writers': ['Agatha Christie', 'Billy Wilder', 'Harry Kurnitz']})
# (65, {'rank': 65, 'name': 'Aliens', 'year': 1986, 'rating': 8.4, 'genre': ['Action', 'Adventure', 'Sci-Fi'], 'certificate': 'R', 'run_time': '2h 17m', 'tagline': "This time there's more.", 'budget': '18500000', 'box_office': '131060248', 'casts': ['Sigourney Weaver', 'Michael Biehn', 'Carrie Henn', 'Paul Reiser', 'Lance Henriksen', 'Bill Paxton', 'William Hope', 'Jenette Goldstein', 'Al Matthews', 'Mark Rolston', 'Ricco Ross', 'Colette Hiller', 'Daniel Kash', 'Cynthia Dale Scott', 'Tip Tipping', 'Trevor Steedman', 'Paul Maxwell', 'Valerie Colgan'], 'directors': ['James Cameron'], 'writers': ['James Cameron', 'David Giler', 'Walter Hill']})
# (66, {'rank': 66, 'name': 'Spider-Man: Into the Spider-Verse', 'year': 2018, 'rating': 8.4, 'genre': ['Animation', 'Action', 'Adventure'], 'certificate': 'PG', 'run_time': '1h 57m', 'tagline': 'Enter a universe where more than one wears the mask.', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Shameik Moore', 'Jake Johnson', 'Hailee Steinfeld', 'Mahershala Ali', 'Brian Tyree Henry', 'Lily Tomlin', 'Luna Lauren Velez', 'Zoë Kravitz', 'John Mulaney', 'Kimiko Glenn', 'Nicolas Cage', 'Kathryn Hahn', 'Liev Schreiber', 'Chris Pine', 'Natalie Morales', 'Edwin R. Habacon', 'Oscar Isaac', 'Greta Lee'], 'directors': ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman'], 'writers': ['Phil Lord', 'Rodney Rothman']})
# (67, {'rank': 67, 'name': 'American Beauty', 'year': 1999, 'rating': 8.4, 'genre': ['Drama'], 'certificate': 'R', 'run_time': '2h 2m', 'tagline': '... look closer', 'budget': '15000000', 'box_office': '356296601', 'casts': ['Kevin Spacey', 'Annette Bening', 'Thora Birch', 'Wes Bentley', 'Mena Suvari', 'Peter Gallagher', 'Allison Janney', 'Chris Cooper', 'Scott Bakula', 'Sam Robards', 'Barry Del Sherman', 'Ara Celi', 'John Cho', 'Fort Atkinson', 'Sue Casey', 'Kent Faulcon', 'Brenda Wehle', 'Lisa Cloud'], 'directors': ['Sam Mendes'], 'writers': ['Alan Ball']})
# (68, {'rank': 68, 'name': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'year': 1964, 'rating': 8.4, 'genre': ['Comedy', 'War'], 'certificate': 'PG', 'run_time': '1h 35m', 'tagline': 'The comedy classic from celebrated director STANLEY KUBRICK', 'budget': '1800000', 'box_office': '9523464', 'casts': ['Peter Sellers', 'George C. Scott', 'Sterling Hayden', 'Keenan Wynn', 'Slim Pickens', 'Peter Bull', 'James Earl Jones', 'Tracy Reed', 'Jack Creley', 'Frank Berry', "Robert O'Neil", 'Glenn Beck', 'Roy Stephens', 'Shane Rimmer', 'Hal Galili', 'Paul Tamarin', 'Laurence Herder', 'Gordon Tanner'], 'directors': ['Stanley Kubrick'], 'writers': ['Stanley Kubrick', 'Terry Southern', 'Peter George']})
# (69, {'rank': 69, 'name': 'The Dark Knight Rises', 'year': 2012, 'rating': 8.4, 'genre': ['Action', 'Drama'], 'certificate': 'PG-13', 'run_time': '2h 44m', 'tagline': 'The Legend Ends', 'budget': '250000000', 'box_office': '1081169825', 'casts': ['Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman', 'Joseph Gordon-Levitt', 'Marion Cotillard', 'Morgan Freeman', 'Michael Caine', 'Matthew Modine', 'Alon Aboutboul', 'Ben Mendelsohn', 'Burn Gorman', 'Daniel Sunjata', 'Aidan Gillen', 'Sam Kennard', 'Aliash Tepina', 'Nestor Carbonell', 'Brett Cullen'], 'directors': ['Christopher Nolan'], 'writers': ['Jonathan Nolan', 'Christopher Nolan', 'David S. Goyer']})
# (70, {'rank': 70, 'name': 'Oldboy', 'year': 2003, 'rating': 8.4, 'genre': ['Action', 'Drama', 'Mystery'], 'certificate': 'R', 'run_time': '2h', 'tagline': '15 years of imprisonment, five days of vengeance', 'budget': '3000000', 'box_office': '15421226', 'casts': ['Choi Min-Sik', 'Yoo Ji-Tae', 'Kang Hye-Jeong', 'Kim Byeong-Ok', 'Dae-Han Ji', 'Dal-Su Oh', 'Seung-Shin Lee', 'Jin-Seo Yoon', 'Tae-Kyung Oh', 'Yoo Yeon-Seok', 'Il-Han Oo', 'Young-Hee Lee', 'Young-Ae Kim', 'Mi Mi Lee', 'Jae-Duk Han', 'Jung Ae Kwak', 'San Kim', 'Chae-Soo Jang'], 'directors': ['Park Chan-Wook'], 'writers': ['Garon Tsuchiya', 'Nobuaki Minegishi', 'Park Chan-Wook']})
# ...
# (228, {'rank': 228, 'name': 'To Be or Not to Be', 'year': 1942, 'rating': 8.2, 'genre': ['Comedy', 'Romance', 'War'], 'certificate': 'Passed', 'run_time': '1h 39m', 'tagline': 'The Picture Everyone Wants To See.', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Carole Lombard', 'Jack Benny', 'Robert Stack', 'Felix Bressart', 'Lionel Atwill', 'Stanley Ridges', 'Sig Ruman', 'Tom Dugan', 'Charles Halton', 'George Lynn', 'Henry Victor', 'Maude Eburne', 'Halliwell Hobbes', 'Miles Mander', 'Rudolph Anders', 'Paul Barrett', 'Sven Hugo Borg', 'Danny Borzage'], 'directors': ['Ernst Lubitsch'], 'writers': ['Melchior Lengyel', 'Edwin Justus Mayer', 'Ernst Lubitsch']})
# (229, {'rank': 229, 'name': 'La haine', 'year': 1995, 'rating': 8.1, 'genre': ['Crime', 'Drama'], 'certificate': 'Not Rated', 'run_time': '1h 38m', 'tagline': 'So far, so good', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Vincent Cassel', 'Hubert Koundé', 'Saïd Taghmaoui', 'Abdel Ahmed Ghili', 'Solo', 'Joseph Momo', 'Héloïse Rauth', 'Rywka Wajsbrot', 'Olga Abrego', 'Laurent Labasse', 'Choukri Gabteni', 'Nabil Ben Mhamed', 'Benoît Magimel', 'Médard Niang', 'Arash Mansour', 'Abdel-Moulah Boujdouni', 'Mathilde Vitry', 'Christian Moro'], 'directors': ['Mathieu Kassovitz'], 'writers': ['Mathieu Kassovitz']})
# (230, {'rank': 230, 'name': 'The Battle of Algiers', 'year': 1966, 'rating': 8.1, 'genre': ['Drama', 'War'], 'certificate': 'Not Rated', 'run_time': '2h 1m', 'tagline': 'The French Colonel...who was forced even to torture! One of the many women...who stopped at nothing to win! The Algerian Street Boy...who became a rebel hero!', 'budget': '800000', 'box_office': '962002', 'casts': ['Brahim Hadjadj', 'Jean Martin', 'Yacef Saadi', 'Samia Kerbash', 'Ugo Paletti', 'Fusia El Kader', 'Mohamed Ben Kassen', 'Franco Moruzzi', 'Tommaso Neri', 'Rouïched', 'Gene Wesson'], 'directors': ['Gillo Pontecorvo'], 'writers': ['Franco Solinas', 'Gillo Pontecorvo']})
# (231, {'rank': 231, 'name': 'Pirates of the Caribbean: The Curse of the Black Pearl', 'year': 2003, 'rating': 8.1, 'genre': ['Action', 'Adventure', 'Fantasy'], 'certificate': 'PG-13', 'run_time': '2h 23m', 'tagline': 'Prepare to be blown out of the water.', 'budget': '140000000', 'box_office': '654264015', 'casts': ['Johnny Depp', 'Geoffrey Rush', 'Orlando Bloom', 'Keira Knightley', 'Jack Davenport', 'Jonathan Pryce', 'Lee Arenberg', 'Mackenzie Crook', "Damian O'Hare", 'Giles New', 'Angus Barnett', 'David Bailie', 'Michael Berry Jr.', 'Isaac C. Singleton Jr.', 'Kevin Mcnally', 'Treva Etienne', 'Zoe Saldana', 'Guy Siner'], 'directors': ['Gore Verbinski'], 'writers': ['Ted Elliott', 'Terry Rossio', 'Stuart Beattie']})
# (232, {'rank': 232, 'name': "Hachi: A Dog's Tale", 'year': 2009, 'rating': 8.1, 'genre': ['Biography', 'Drama', 'Family'], 'certificate': 'G', 'run_time': '1h 33m', 'tagline': 'A true story of faith, devotion and undying love.', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Richard Gere', 'Joan Allen', 'Cary-Hiroyuki Tagawa', 'Sarah Roemer', 'Jason Alexander', 'Erick Avari', 'Davenia Mcfadden', 'Robbie Sublett', 'Kevin Decoste', 'Rob Degnan', 'Tora Hallström', 'Donna Sorbello', 'Frank S. Aronson', 'Troy Doherty', 'Ian Sherman', 'Timothy Crowe', 'Denece Ryland', 'Blake Friedman'], 'directors': ['Lasse Hallström'], 'writers': ['Stephen P. Lindsey', 'Kaneto Shindô']})
# (233, {'rank': 233, 'name': 'The Grapes of Wrath', 'year': 1940, 'rating': 8.1, 'genre': ['Drama'], 'certificate': 'Passed', 'run_time': '2h 9m', 'tagline': 'The thousands who have read the book will know why WE WILL NOT SELL ANY CHILDREN TICKETS to see this picture!', 'budget': '800000', 'box_office': '800000 (estimated)', 'casts': ['Henry Fonda', 'Jane Darwell', 'John Carradine', 'Charley Grapewin', 'Dorris Bowdon', 'Russell Simpson', 'O.Z. Whitehead', 'John Qualen', 'Eddie Quillan', 'Zeffie Tilbury', 'Frank Sully', 'Frank Darien', 'Darryl Hickman', 'Shirley Mills', 'Roger Imhof', 'Grant Mitchell', 'Charles D. Brown', 'John Arledge'], 'directors': ['John Ford'], 'writers': ['Nunnally Johnson', 'John Steinbeck']})
# (234, {'rank': 234, 'name': 'Jai Bhim', 'year': 2021, 'rating': 8.8, 'genre': ['Crime', 'Drama', 'Mystery'], 'certificate': 'TV-MA', 'run_time': '2h 44m', 'tagline': 'imeDramaMystery', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Suriya', 'Lijo Mol Jose', 'Manikandan K.', 'Rajisha Vijayan', 'Prakash Raj', 'Rao Ramesh', 'Guru Somasundaram', 'M.S. Bhaskar', 'V. Jayaprakash', 'Sibi Thomas', 'Ilavarasu', 'Jayarao', 'Sujatha Sivakumar', 'Ravi Venkatraman', 'Tamizh', 'Kumaravel', 'Supergood Subramani', 'Bala Hasan'], 'directors': ['T.J. Gnanavel'], 'writers': ['T.J. Gnanavel', 'Rajendra Sapre']})
# (235, {'rank': 235, 'name': 'My Father and My Son', 'year': 2005, 'rating': 8.2, 'genre': ['Drama', 'Family'], 'certificate': 'Not Rated', 'run_time': '1h 52m', 'tagline': 'Give him a room dad, he has no place to go...', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Çetin Tekindor', 'Fikret Kuskan', 'Hümeyra', 'Ege Tanman', 'Serif Sezer', 'Yetkin Dikinciler', 'Binnur Kaya', 'Mahmut Gökgöz', 'Nergis Çorakçi', 'Bilge Sen', 'Tuba Büyüküstün', 'Özge Özberk', 'Erdal Tosun', 'Halit Ergenç', 'Tugyan Akay Kavukçu', 'Ege Kaya', 'Muzaffer Demirel', 'Burak Akçakaya'], 'directors': ['Çagan Irmak'], 'writers': ['Çagan Irmak']})
# (236, {'rank': 236, 'name': 'Amores Perros', 'year': 2000, 'rating': 8.1, 'genre': ['Drama', 'Thriller'], 'certificate': 'R', 'run_time': '2h 34m', 'tagline': 'Love. Betrayal. Death.', 'budget': '2000000', 'box_office': '20908467', 'casts': ['Emilio Echevarría', 'Gael García Bernal', 'Goya Toledo', 'Álvaro Guerrero', 'Vanessa Bauche', 'Jorge Salinas', 'Marco Pérez', 'Rodrigo Murray', 'Humberto Busto', 'Gerardo Campbell', 'Rosa María Bianchi', 'Dunia Saldívar', 'Adriana Barraza', 'José Sefami', 'Lourdes Echevarría', 'Laura Almela', 'Ricardo Dalmacci', 'Gustavo Sánchez Parra'], 'directors': ['Alejandro G. Iñárritu'], 'writers': ['Guillermo Arriaga']})
# (237, {'rank': 237, 'name': 'Rebecca', 'year': 1940, 'rating': 8.1, 'genre': ['Drama', 'Film-Noir', 'Mystery'], 'certificate': 'Approved', 'run_time': '2h 10m', 'tagline': 'THE MIGHTY NOVEL LEAPS TO TURBULENT LIFE ON THE SCREEN! (Print Ad- Syracuse Herald-American, ((Syracuse, NY)) 24 March 1940)', 'budget': '1288000', 'box_office': '72275', 'casts': ['Laurence Olivier', 'Joan Fontaine', 'George Sanders', 'Judith Anderson', 'Nigel Bruce', 'Reginald Denny', 'C. Aubrey Smith', 'Gladys Cooper', 'Florence Bates', 'Melville Cooper', 'Leo G. Carroll', 'Leonard Carey', 'Lumsden Hare', 'Edward Fielding', 'Philip Winter', 'Forrester Harvey', 'Bunny Beatty', 'Billy Bevan'], 'directors': ['Alfred Hitchcock'], 'writers': ['Daphne Du Maurier', 'Robert E. Sherwood', 'Joan Harrison']})
# (238, {'rank': 238, 'name': 'Cool Hand Luke', 'year': 1967, 'rating': 8.1, 'genre': ['Crime', 'Drama'], 'certificate': 'GP', 'run_time': '2h 7m', 'tagline': '"What we\'ve got here is failure to communicate."', 'budget': '3200000', 'box_office': '67', 'casts': ['Paul Newman', 'George Kennedy', 'Strother Martin', 'J.D. Cannon', 'Lou Antonio', 'Robert Drivas', 'Jo Van Fleet', 'Clifton James', 'Morgan Woodward', 'Luke Askew', 'Marc Cavell', 'Richard Davalos', 'Robert Donner', 'Warren Finnerty', 'Dennis Hopper', 'John Mcliam', 'Wayne Rogers', 'Harry Dean Stanton'], 'directors': ['Stuart Rosenberg'], 'writers': ['Donn Pearce', 'Frank Pierson', 'Hal Dresner']})
# (239, {'rank': 239, 'name': 'The Handmaiden', 'year': 2016, 'rating': 8.1, 'genre': ['Drama', 'Romance', 'Thriller'], 'certificate': 'Not Rated', 'run_time': '2h 25m', 'tagline': 'Never did they expect to get into a controversial relationship...', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Kim Min-Hee', 'Ha Jung-Woo', 'Cho Jin-Woong', 'Moon So-Ri', 'Kim Tae-Ri', 'Yong-Nyeo Lee', 'Min-Chae Yoo', 'Dong-Hwi Lee', 'Kim Hae-Sook', 'Kyu-Jung Lee', 'Si-Eun Kim', 'Si-Yeon Ha', 'Rina Takagi', 'Geun-Hee Won', 'Jong-Dae Kim', 'Han-Sun Jang', 'Eun-Yeong Kim', 'Ri-Woo Kim'], 'directors': ['Park Chan-Wook'], 'writers': ['Sarah Waters', 'Chung Seo-Kyung', 'Park Chan-Wook']})
# (240, {'rank': 240, 'name': 'The 400 Blows', 'year': 1959, 'rating': 8.1, 'genre': ['Crime', 'Drama'], 'certificate': 'Not Rated', 'run_time': '1h 39m', 'tagline': 'From the Vanguard of New Film-Makers Comes an Extraordinary Motion Picture', 'budget': 'Not Available', 'box_office': '127244', 'casts': ['Jean-Pierre Léaud', 'Albert Rémy', 'Claire Maurier', 'Guy Decomble', 'Georges Flamant', 'Patrick Auffay', 'Daniel Couturier', 'François Nocher', 'Richard Kanayan', 'Renaud Fontanarosa', 'Michel Girard', 'Serge Moati', 'Bernard Abbou', 'Jean-François Bergouignan', 'Michel Lesignor', 'Luc Andrieux', 'Robert Beauvais', 'Bouchon'], 'directors': ['François Truffaut'], 'writers': ['François Truffaut', 'Marcel Moussy']})
# (241, {'rank': 241, 'name': 'The Sound of Music', 'year': 1965, 'rating': 8.1, 'genre': ['Biography', 'Drama', 'Family'], 'certificate': 'G', 'run_time': '2h 52m', 'tagline': 'RADIANCE THAT FLOODS THE SCREEN...AND WARMS THE HEART!', 'budget': '8200000', 'box_office': '159428329', 'casts': ['Julie Andrews', 'Christopher Plummer', 'Eleanor Parker', 'Richard Haydn', 'Peggy Wood', 'Charmian Carr', 'Heather Menzies-Urich', 'Nicholas Hammond', 'Duane Chase', 'Angela Cartwright', 'Debbie Turner', 'Kym Karath', 'Anna Lee', 'Portia Nelson', 'Ben Wright', 'Daniel Truhitte', 'Norma Varden', 'Gilchrist Stuart'], 'directors': ['Robert Wise'], 'writers': ['Georg Hurdalek', 'Howard Lindsay', 'Russel Crouse']})
# (242, {'rank': 242, 'name': 'It Happened One Night', 'year': 1934, 'rating': 8.1, 'genre': ['Comedy', 'Romance'], 'certificate': 'Passed', 'run_time': '1h 45m', 'tagline': 'Two great lovers of the screen in the grandest of romantic comedies !', 'budget': '325000', 'box_office': '11477', 'casts': ['Clark Gable', 'Claudette Colbert', 'Walter Connolly', 'Roscoe Karns', 'Jameson Thomas', 'Alan Hale', 'Arthur Hoyt', 'Blanche Friderici', 'Charles C. Wilson', 'Ernie Adams', 'Jessie Arnold', 'Irving Bacon', 'William Bailey', 'William Begg', 'William A. Boardway', 'Ward Bond', 'Harry C. Bradley', 'George P. Breakston'], 'directors': ['Frank Capra'], 'writers': ['Robert Riskin', 'Samuel Hopkins Adams']})
# (243, {'rank': 243, 'name': 'Persona', 'year': 1966, 'rating': 8.1, 'genre': ['Drama', 'Thriller'], 'certificate': 'Not Rated', 'run_time': '1h 23m', 'tagline': 'A new film by Ingmar Bergman', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Bibi Andersson', 'Liv Ullmann', 'Margaretha Krook', 'Gunnar Björnstrand', 'Jörgen Lindström'], 'directors': ['Ingmar Bergman'], 'writers': ['Ingmar Bergman']})
# (244, {'rank': 244, 'name': 'Life of Brian', 'year': 1979, 'rating': 8.0, 'genre': ['Comedy'], 'certificate': 'R', 'run_time': '1h 34m', 'tagline': 'A motion picture destined to offend nearly two thirds of the civilized world. And severely annoy the other third.', 'budget': '4000000', 'box_office': '20745728', 'casts': ['Graham Chapman', 'John Cleese', 'Michael Palin', 'Terry Gilliam', 'Eric Idle', 'Terry Jones', 'Terence Bayler', 'Carol Cleveland', 'Kenneth Colley', 'Neil Innes', 'Charles Mckeown', 'John Young', 'Gwen Taylor', 'Sue Jones-Davies', 'Peter Brett', 'John Case', 'Chris Langham', 'Andrew Maclachlan'], 'directors': ['Terry Jones'], 'writers': ['Graham Chapman', 'John Cleese', 'Terry Gilliam']})
# (245, {'rank': 245, 'name': 'The Iron Giant', 'year': 1999, 'rating': 8.1, 'genre': ['Animation', 'Action', 'Adventure'], 'certificate': 'PG', 'run_time': '1h 26m', 'tagline': 'Some secrets are too huge to hide', 'budget': '70000000', 'box_office': '23335817', 'casts': ['Eli Marienthal', 'Harry Connick Jr.', 'Jennifer Aniston', 'Vin Diesel', 'James Gammon', 'Cloris Leachman', 'Christopher Mcdonald', 'John Mahoney', 'M. Emmet Walsh', 'Jack Angel', 'Bob Bergen', 'Mary Kay Bergman', 'Michael Bird', 'Devon Cole Borisoff', 'Rodger Bumpass', 'Robert Clotworthy', 'Jennifer Darling', 'Zack Eginton'], 'directors': ['Brad Bird'], 'writers': ['Tim Mccanlies', 'Brad Bird', 'Ted Hughes']})
# (246, {'rank': 246, 'name': 'The Help', 'year': 2011, 'rating': 8.1, 'genre': ['Drama'], 'certificate': 'PG-13', 'run_time': '2h 26m', 'tagline': 'Change begins with a whisper.', 'budget': '25000000', 'box_office': '216639112', 'casts': ['Viola Davis', 'Emma Stone', 'Octavia Spencer', 'Bryce Dallas Howard', 'Jessica Chastain', "Ahna O'Reilly", 'Allison Janney', 'Anna Camp', 'Eleanor Henry', 'Emma Henry', 'Christopher Lowell', 'Cicely Tyson', 'Mike Vogel', 'Sissy Spacek', 'Brian Kerwin', 'Wes Chatham', 'Aunjanue Ellis', 'Ted Welch'], 'directors': ['Tate Taylor'], 'writers': ['Tate Taylor', 'Kathryn Stockett']})
# (247, {'rank': 247, 'name': 'Dersu Uzala', 'year': 1975, 'rating': 8.2, 'genre': ['Adventure', 'Biography', 'Drama'], 'certificate': 'G', 'run_time': '2h 22m', 'tagline': "There is man and beast at nature's mercy. There is awe and love and reverence. And there is the man called...", 'budget': '4000000', 'box_office': '14480', 'casts': ['Maksim Munzuk', 'Yuriy Solomin', 'Mikhail Bychkov', 'Vladimir Khrulyov', 'V. Lastochkin', 'Stanislav Marin', 'Igor Sykhra', 'Vladimir Sergiyakov', 'Yanis Yakobsons', 'Vladimir Khlestov', 'G. Polunin', 'V. Koldin', 'M. Tetov', 'S. Sinyavskiy', 'Vladimir Sverba', 'V. Ignatov', 'Vladimir Kremena', 'Aleksandr Pyatkov'], 'directors': ['Akira Kurosawa'], 'writers': ['Akira Kurosawa', 'Yuriy Nagibin', 'Vladimir Arsenev']})
# (248, {'rank': 248, 'name': 'Aladdin', 'year': 1992, 'rating': 8.0, 'genre': ['Animation', 'Adventure', 'Comedy'], 'certificate': 'G', 'run_time': '1h 30m', 'tagline': 'Wish granted! (DVD re-release)', 'budget': 'Not Available', 'box_office': 'Not Available', 'casts': ['Scott Weinger', 'Robin Williams', 'Linda Larkin', 'Jonathan Freeman', 'Frank Welker', 'Gilbert Gottfried', 'Douglas Seale', 'Charlie Adler', 'Jack Angel', 'Corey Burton', 'Philip L. Clarke', 'Jim Cummings', 'Jennifer Darling', 'Debi Derryberry', 'Bruce Gooch', 'Jerry Houser', 'Vera Lockwood', 'Sherry Lynn'], 'directors': ['Ron Clements', 'John Musker'], 'writers': ['Ron Clements', 'John Musker', 'Ted Elliott']})
# (249, {'rank': 249, 'name': 'Gandhi', 'year': 1982, 'rating': 8.0, 'genre': ['Biography', 'Drama', 'History'], 'certificate': 'PG', 'run_time': '3h 11m', 'tagline': 'His Triumph Changed The World Forever.', 'budget': '22000000', 'box_office': '52767889', 'casts': ['Ben Kingsley', 'John Gielgud', 'Rohini Hattangadi', 'Roshan Seth', 'Candice Bergen', 'Edward Fox', 'Trevor Howard', 'John Mills', 'Martin Sheen', 'Ian Charleson', 'Günther Maria Halmer', 'Athol Fugard', 'Saeed Jaffrey', 'Geraldine James', 'Alyque Padamsee', 'Amrish Puri', 'Ian Bannen', 'Michael Bryant'], 'directors': ['Richard Attenborough'], 'writers': ['John Briley']})
# (250, {'rank': 250, 'name': 'Dances with Wolves', 'year': 1990, 'rating': 8.0, 'genre': ['Adventure', 'Drama', 'Western'], 'certificate': 'PG-13', 'run_time': '3h 1m', 'tagline': 'Inside everyone is a frontier waiting to be discovered.', 'budget': '22000000', 'box_office': '424208848', 'casts': ['Kevin Costner', 'Mary Mcdonnell', 'Graham Greene', 'Rodney A. Grant', "Floyd 'Red Crow' Westerman", 'Tantoo Cardinal', 'Robert Pastorelli', 'Charles Rocket', 'Maury Chaykin', 'Jimmy Herman', 'Nathan Lee Chasing His Horse', 'Michael Spears', 'Jason R. Lone Hill', 'Tony Pierce', 'Doris Leader Charge', 'Tom Everett', 'Larry Joshua', 'Kirk Baltz'], 'directors': ['Kevin Costner'], 'writers': ['Michael Blake']})

# %% [markdown]
# Which genres have the most movies?
#
# Based on the plot, Drama, Adventure, and Comedy are the top three genres with highest number of movies.

# %%
# Count genre occurrences
genre_count = {}
for key in ds_movies.keys():
    for genre in ds_movies[key]['genre']:
        if genre in genre_count:
            genre_count[genre] += 1
        else:
            genre_count[genre] = 1

# Plotting
for key in genre_count.keys():
  print(f"{key}: {genre_count[key]}")
genres = list(genre_count.keys())
counts = list(genre_count.values())

plt.figure(figsize=(10, 6))
plt.bar(genres, counts, color='skyblue')
plt.xlabel('Genres')
plt.ylabel('Frequency')
plt.title('Frequency Plot of Movie Genres')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Drama: 177
# Crime: 51
# Action: 50
# Biography: 29
# History: 10
# Adventure: 60
# Western: 7
# Romance: 23
# Sci-Fi: 20
# Fantasy: 14
# Mystery: 31
# Family: 13
# Thriller: 30
# War: 23
# Comedy: 45
# Animation: 23
# Music: 4
# Horror: 5
# Film-Noir: 4
# Musical: 1
# Sport: 5

# %% [markdown]
# Mention the 3 genres with the best average rating

# %%
genres = set()

# Get the different genres
for movie in ds_movies.values():
  genres.update(movie['genre'])

# Create a DS with the genres matching their ratings
genre_ratings = {}
for genre in genres:
  genre_ratings[genre] = {}
  genre_ratings[genre]["ratings"] = []
  for movie in ds_movies.values():
    if genre in movie["genre"]:
      genre_ratings[genre]["ratings"].append(movie["rating"])
  genre_ratings[genre]["avg_rating"] = round(
      sum(genre_ratings[genre]["ratings"]) / \
      len(genre_ratings[genre]["ratings"]), 4
  )

# Get the top three genres
sorted_genres = sorted(
    genre_ratings.items(),
    key=lambda x: x[1]['avg_rating'],
    reverse=True
)

# Record the top three genres with the highest average ratings
top_three_genres = sorted_genres[:3]

print("\nTop Three Genres with Highest Average Ratings:")
for genre, info in top_three_genres:
    print(f"    {genre}: {info['avg_rating']}")
# Out:
# Top Three Genres with Highest Average Ratings:
#     Music: 8.4
#     Crime: 8.3608
#     Sci-Fi: 8.36

# %% [markdown]
# ## **Mutivariate Analysis**

# %% [markdown]
# Mention the best 10 movies according to the rating

# %%
# Sort the movies by their rating
sorted_movies = sorted(
    ds_movies.items(),
    key=lambda x: x[1]['rating'],
    reverse=True
)

# Record the top ten movies with the highest ratings
top_ten_movies = sorted_movies[:10]

print("Top Ten Movies with Highest Ratings:")
for element, movie in top_ten_movies:
    print(f"    {movie['name']}: {movie['rating']}")
# Out:
# Top Ten Movies with Highest Ratings:
#     The Shawshank Redemption: 9.3
#     The Godfather: 9.2
#     The Dark Knight: 9.0
#     The Godfather Part II: 9.0
#     12 Angry Men: 9.0
#     Schindler's List: 9.0
#     The Lord of the Rings: The Return of the King: 9.0
#     Pulp Fiction: 8.9
#     The Lord of the Rings: The Fellowship of the Ring: 8.8
#     The Good, the Bad and the Ugly: 8.8

# %% [markdown]
# Mention the 10 movies that generated the most profit, along with the profit of each one

# %%
# Calculate profit for each movie and add it to the dictionary
for key in ds_movies:
  try:
    ds_movies[key]['profit'] = \
      float(ds_movies[key]['box_office'].replace("$","")) - \
      float(ds_movies[key]['budget'].replace("$",""))
  except:
    ds_movies[key]['profit'] = 0

# Sort movies based on profit in descending order
sorted_movies_by_profit = sorted(
    ds_movies.items(),
    key=lambda x: x[1]['profit'],
    reverse=True
)

# Print sorted movies
print("Top Ten Movies Sorted by Profit:")
counter = 0
for movie in sorted_movies_by_profit:
  if (counter < 10):
    counter += 1
    if movie[1]['profit'] >= 0:
      print(f"    {movie[1]['name']}: USD {movie[1]['profit']}")
    else:
      print(f"    {movie[1]['name']}: - USD {movie[1]['profit']*-1}")


# Extract movie names and profits
top_10_movies = sorted_movies_by_profit[:10]
movie_names = [movie[1]['name'] for movie in top_10_movies]
profits = [movie[1]['profit'] for movie in top_10_movies]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(movie_names, profits, color='skyblue')
plt.xlabel('Movie')
plt.ylabel('Profit ($)')
plt.title('Top 10 Movies by Profit')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Top Ten Movies Sorted by Profit:
#     Avengers: Endgame: USD 2443439100.0
#     Avengers: Infinity War: USD 1731415039.0
#     Spider-Man: No Way Home: USD 1721847111.0
#     Top Gun: Maverick: USD 1318732821.0
#     Harry Potter and the Deathly Hallows: Part 2: USD 1217359942.0
#     The Lord of the Rings: The Return of the King: USD 1052457748.0
#     Jurassic Park: USD 1046802321.0
#     Joker: USD 1019458282.0
#     The Lion King: USD 923511805.0
#     Toy Story 3: USD 867316101.0

# %% [markdown]
# Which genres invest the most in making films?

# %%
# Create a DS with the genres matching their budgets
genre_budgets = {}
for genre in genres:
  genre_budgets[genre] = {}
  genre_budgets[genre]["budgets"] = []
  for movie in ds_movies.values():
    if genre in movie["genre"]:
      try:
        genre_budgets[genre]["budgets"].append(float(movie["budget"]))
      except:
        pass # Record nothing if there is no data
  genre_budgets[genre]["avg_budget"] = round(
      sum(genre_budgets[genre]["budgets"]) / \
      len(genre_budgets[genre]["budgets"]), 4
  )

# Get the top three budgets
sorted_budgets = sorted(
    genre_budgets.items(),
    key=lambda x: x[1]['avg_budget'],
    reverse=True
)

# Record the top ten genres with the highest average budgets
top_ten_bugets = sorted_budgets[:10]
top_ten_budget_genre_names = [
    movie[0] for movie in top_ten_bugets
]
top_ten_budget_genre_budgets = [
    int(movie[1]['avg_budget']) for movie in top_ten_bugets
]

print("\nTop Ten Genres with Highest Average Budgets:")
for genre, info in top_ten_bugets:
    print(f"    {genre}: USD {info['avg_budget']}")

# Plot the results
plt.figure(figsize=(8, 5))
plt.barh(top_ten_budget_genre_names, top_ten_budget_genre_budgets, color='skyblue')
plt.xlabel('Budget Mean')
plt.title('Genre vs Budget Mean')

plt.tight_layout()
plt.show()
# Out:
# Top Ten Genres with Highest Average Budgets:
#     Animation: USD 241923529.4118
#     Action: USD 142507068.1818
#     Adventure: USD 117160367.4107
#     Sci-Fi: USD 70900000.0
#     Comedy: USD 53356900.6053
#     Fantasy: USD 48187428.8462
#     Family: USD 45300875.0
#     Drama: USD 35243085.0284
#     Biography: USD 30273913.0435
#     Crime: USD 28261839.5714

# %%
# RUN THIS CODE ONLY ONCE, OTHERWISE RE-RUN THE WHOLE BOOK

# Converting runtime to a minutes equivalent
def convert_run_time(run_time):
    # Split the run_time string into hours and minutes
    if 'not available' == run_time.lower():
      hours = '0'
      minutes = '0m'
    else:
      if 'm' not in run_time:
        minutes = '0m'
        hours = run_time.replace('h', '')
      elif 'h' not in run_time:
        hours = '0'
        minutes = run_time.replace('m','')
      else:
        hours, minutes = run_time.split('h ')
    # Convert hours and minutes to integers and calculate total minutes
    total_minutes = int(hours) * 60 + int(minutes[:-1])
    return total_minutes

# Update run_time in ds_movies to numerical format in minutes
for movie in ds_movies.keys():
    ds_movies[movie]['run_time'] = \
      convert_run_time(ds_movies[movie]['run_time'])

# %% [markdown]
# Identify if there are one or several variables that contribute significantly to maximizing profit
#
# As you can tell:
# 1. There are some certificates that seem to be more correlated to higher profits.
# 2. The earlier the movie, the lower the profit.
# 3. The higher the run time, the higher the profit. There seems to be a kind of trend, but it is not granted, since a lot of movies are bringing zero profit based on their run time.
# 4. The higher the box office, the higher the profit.
# 5. There is not enough data to conclude about the budget, however, it can be somehow tell that there is a bound line around USD 500 millions, at which the profit tends to grow when the budget grows, meaning that better sponsored movies tend to bring higher profit, and after it, the trend tends to become inverse, which means that at this point, more higher profits.

# %%
# Select features for plotting
features = [
    'year', 'rating',
    'budget', 'box_office',
    'certificate', 'run_time']

for i, feature in enumerate(features, 1):
    plt.figure(figsize=(40, 5))
    plt.subplot(1, len(features), i)
    feature_values = [
        movie_value.get(feature, None) \
        for movie_value in ds_movies.values()
    ]
    # Remove text values from the feature values
    if (feature in ["box_office", "budget"]):
      for value in range(len(feature_values)):
        try:
          feature_values[value] = float(feature_values[value])
        except:
          feature_values[value] = 0.0

    profit_values = [
        movie_value['profit'] for movie_value in ds_movies.values()
    ]
    plt.scatter(feature_values, profit_values)
    plt.xlabel(feature)
    plt.xticks(rotation=45)
    plt.ylabel('Profit')
    plt.title(f'{feature} vs Profit')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# What are the 5 most successful directors in terms of rating and profit. Of the data that supports it.

# %%
directors_dirty = set()

# Get the different actors
for movie in ds_movies.values():
  directors_dirty.update(movie['directors'])

# Get directors without their sub-role in the film
directors = {element.split('(')[0] for element in directors_dirty}

# Get the ratings and profits for each director
director_success = {}
for director in directors:
  director_success[director] = {}
  director_success[director]['ratings'] = []
  director_success[director]['profits'] = []
  for key in ds_movies.keys():
    if director in ds_movies[key]['directors']:
      director_success[director]['ratings'].append(
          float(ds_movies[key]['rating'])
      )
      director_success[director]['profits'].append(
          float(ds_movies[key]['profit'])
      )

  # Compute the mean of the ratings
  if (len(director_success[director]['ratings']) > 0):
    director_success[director]['rating_mean'] = \
      round(sum(director_success[director]['ratings']) / \
      len(director_success[director]['ratings']), 4)
  else:
    director_success[director]['rating_mean'] = 0

  # Compute the mean of the profits
  if (len(director_success[director]['profits']) > 0):
    director_success[director]['profit_mean'] = \
      round(sum(director_success[director]['profits']) / \
      len(director_success[director]['profits']), 4)
  else:
    director_success[director]['profit_mean'] = 0

# Sort directors by mean rating in descending order
sorted_directors_by_rating = sorted(
    director_success.items(),
    key=lambda x: x[1]['rating_mean'],
    reverse=True
)

print("Directors sorted by mean rating (highest to lowest):")
director_count = 0
for director, data in sorted_directors_by_rating:
    print(f"{director}: {data['rating_mean']}")
    director_count += 1
    if director_count > 4:
      break

# Sort directors by mean profit in descending order
sorted_directors_by_profit = sorted(
    director_success.items(),
    key=lambda x: x[1]['profit_mean'],
    reverse=True
)

print("\nDirectors sorted by mean profit (highest to lowest):")
director_count = 0
for director, data in sorted_directors_by_profit:
    print(f"{director}: USD {data['profit_mean']}")
    director_count += 1
    if director_count > 4:
      break

# Plotting the results
top5_directors_by_rating = sorted_directors_by_rating[:5]
top5r_director_names = [
    movie[0] for movie in top5_directors_by_rating
]
top5r_director_ratings = [
    movie[1]['rating_mean'] for movie in top5_directors_by_rating
]

top5_directors_by_profit = sorted_directors_by_profit[:5]
top5p_director_names = [
    movie[0] for movie in top5_directors_by_profit
]
top5p_director_profits = [
    int(movie[1]['profit_mean']) for movie in top5_directors_by_profit
]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Rating Mean subplot
ax1.bar(top5r_director_names, top5r_director_ratings, color='skyblue')
for i in range(len(top5_directors_by_rating)):
    ax1.text(
        i, top5r_director_ratings[i],
        f"{top5r_director_ratings[i]:.2f}",
        ha='center', va='bottom'
    )
ax1.set_ylabel('Rating Mean')
ax1.set_title('Director vs Rating Mean')

# Profit Mean subplot
ax2.bar(
    top5p_director_names,
    top5p_director_profits,
    color='lightgreen'
)
for i in range(len(top5p_director_names)):
    ax2.text(
        i, top5p_director_profits[i],
        f"USD {top5p_director_profits[i]}",
        ha='center', va='bottom'
    )
ax2.set_ylabel('Profit Mean')
ax2.set_title('Director vs Profit Mean')

plt.tight_layout()

# Display the plot
plt.show()
# Out:
# Directors sorted by mean rating (highest to lowest):
# Frank Darabont: 8.95
# Francis Ford Coppola: 8.9
# Peter Jackson: 8.8667
# T.J. Gnanavel: 8.8
# Lilly Wachowski: 8.7
#
# Directors sorted by mean profit (highest to lowest):
# Joe Russo: USD 2087427069.5
# Anthony Russo: USD 2087427069.5
# Jon Watts: USD 1721847111.0
# Joseph Kosinski: USD 1318732821.0
# David Yates: USD 1217359942.0

# %% [markdown]
# Who are the 5 most successful actors in terms of rating and earnings. Of the data that supports it.

# %%
actors = set()

# Get the different actors and actress
for movie in ds_movies.values():
  actors.update(movie['casts'])

# Get the ratings and profits for each actor or actress
actor_success = {}
for actor in actors:
  actor_success[actor] = {}
  actor_success[actor]['ratings'] = []
  actor_success[actor]['profits'] = []
  for key in ds_movies.keys():
    if actor in ds_movies[key]['casts']:
      actor_success[actor]['ratings'].append(
          float(ds_movies[key]['rating'])
      )
      actor_success[actor]['profits'].append(
          float(ds_movies[key]['profit'])
      )
      if actor.lower() == 'paul rudd':
        print(ds_movies[key])

  # Compute the mean of the ratings
  if (len(actor_success[actor]['ratings']) > 0):
    actor_success[actor]['rating_mean'] = \
      round(sum(actor_success[actor]['ratings']) / \
      len(actor_success[actor]['ratings']), 4)
  else:
    actor_success[actor]['rating_mean'] = 0

  # Compute the mean of the profits
  if (len(actor_success[actor]['profits']) > 0):
    actor_success[actor]['profit_mean'] = \
      round(sum(actor_success[actor]['profits']) / \
      len(actor_success[actor]['profits']), 4)
  else:
    actor_success[actor]['profit_mean'] = 0

# Sort actors by mean rating in descending order
sorted_actors_by_rating = sorted(
    actor_success.items(),
    key=lambda x: x[1]['rating_mean'],
    reverse=True
)

print("Actors sorted by mean rating (highest to lowest):")
actor_count = 0
for actor, data in sorted_actors_by_rating:
    print(f"{actor}: {data['rating_mean']} - {data['ratings']}")
    actor_count += 1
    if actor_count > 4:
      break

# Sort actors by mean profit in descending order
sorted_actors_by_profit = sorted(
    actor_success.items(),
    key=lambda x: x[1]['profit_mean'],
    reverse=True
)

print("\Actors sorted by mean profit (highest to lowest):")
actor_count = 0
for actor, data in sorted_actors_by_profit:
    print(f"{actor}: USD {data['profit_mean']} - {data['profits']}")
    actor_count += 1
    if actor_count > 4:
      break

# Plotting the results
top5_actors_by_rating = sorted_actors_by_rating[:5]
top5r_actor_names = [
    movie[0] for movie in top5_actors_by_rating
]
top5r_actor_ratings = [
    movie[1]['rating_mean'] for movie in top5_actors_by_rating
]

top5_actors_by_profit = sorted_actors_by_profit[:5]
top5p_actor_names = [
    movie[0] for movie in top5_actors_by_profit
]
top5p_actor_profits = [
    int(movie[1]['profit_mean']) for movie in top5_actors_by_profit
]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Rating Mean subplot
ax1.bar(top5r_actor_names, top5r_actor_ratings, color='skyblue')
for i in range(len(top5_actors_by_rating)):
    ax1.text(
        i, top5r_actor_ratings[i],
        f"{top5r_actor_ratings[i]:.2f}",
        ha='center', va='bottom'
    )
ax1.set_ylabel('Rating Mean')
ax1.set_title('Actor vs Rating Mean')

# Profit Mean subplot
ax2.bar(top5p_actor_names, top5p_actor_profits, color='lightgreen')
for i in range(len(top5p_actor_names)):
    ax2.text(
        i, top5p_actor_profits[i],
        f"USD {top5p_actor_profits[i]}",
        ha='center', va='bottom'
    )
ax2.set_ylabel('Profit Mean')
ax2.set_title('Actor vs Profit Mean')

plt.tight_layout()

# Display the plot
plt.show()
# Out:
# {'rank': 78, 'name': 'Avengers: Endgame', 'year': 2019, 'rating': 8.4, 'genre': ['Action', 'Adventure', 'Drama'], 'certificate': 'PG-13', 'run_time': 181, 'tagline': 'Avenge the fallen.', 'budget': '356000000', 'box_office': '2799439100', 'casts': ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Chris Hemsworth', 'Scarlett Johansson', 'Jeremy Renner', 'Don Cheadle', 'Paul Rudd', 'Benedict Cumberbatch', 'Chadwick Boseman', 'Brie Larson', 'Tom Holland', 'Karen Gillan', 'Zoe Saldana', 'Evangeline Lilly', 'Tessa Thompson', 'Rene Russo', 'Elizabeth Olsen'], 'directors': ['Anthony Russo', 'Joe Russo'], 'writers': ['Christopher Markus', 'Stephen Mcfeely', 'Stan Lee'], 'profit': 2443439100.0}
# Actors sorted by mean rating (highest to lowest):
# Bob Gunton: 9.3 - [9.3]
# Renee Blaine: 9.3 - [9.3]
# Scott Mann: 9.3 - [9.3]
# James Whitmore: 9.3 - [9.3]
# David Proval: 9.3 - [9.3]
# \Actors sorted by mean profit (highest to lowest):
# Jeremy Renner: USD 2443439100.0 - [2443439100.0]
# Paul Rudd: USD 2443439100.0 - [2443439100.0]
# Rene Russo: USD 2443439100.0 - [2443439100.0]
# Evangeline Lilly: USD 2443439100.0 - [2443439100.0]
# Tessa Thompson: USD 2443439100.0 - [2443439100.0]

# %% [markdown]
# Who are the top 3 writers according to the number of films in which they participate.

# %%
writers = set()

# Get the different actors and actress
for movie in ds_movies.values():
  writers.update(movie['writers'])

# Count the number of films for every writer
writers_films_number = {}
for writer in writers:
  writers_films_number[writer] = 0
  for key in ds_movies.keys():
    if writer in ds_movies[key]['writers']:
      writers_films_number[writer] += 1

# Sort writers by number of films in descending order
sorted_writers_by_number_of_films = sorted(
    writers_films_number.items(),
    key=lambda x: x[1],
    reverse=True
)

print("Top 3 writers sorted by number of films (highest to lowest):")
writers_count = 0
for writer, data in sorted_writers_by_number_of_films:
    print(f"{writer}: {data}")
    writers_count += 1
    if (writers_count > 2):
      break
# Out:
# Top 3 writers sorted by number of films (highest to lowest):
# Christopher Nolan: 7
# Stanley Kubrick: 7
# Akira Kurosawa: 6

# %% [markdown]
# Explain the relationship/distribution of certificates between different genres.
#
# Given the heatmap, some genres rise up higher than others, those are:
#
# 1.   **Mystery**: Most of these movies are Rated, which means that the movie is allowed only for people over 17.
# 2.   **Thriller**: Most of these movies are Rated, which means that the movie is allowed only for people over 17.
# 3.   **Biography**: Most of these movies are Rated, which means that the movie is allowed only for people over 17. But there are some of them emerging to be G, PG, or PG-13. Which means that these movies start trending to younger audiences.
# 4.   **Adventure**: Most of these movies are G, PG, or PG-13. Which means that these movies tend to be more tilted towards the younghest in the room.
# 5.   **Comedy**: These are movies mixed between multiple categories, but their trend towards younger people is clear.
# 6.   **Drama**: These movies are heavily tilted towards R, which means that most of these movies are only for people over 17.
# 7.   **Action**: These movies are equilibrated between PG, PG-13, and R, which means there is a wide variety of movie types in this category.
# 8.   **Animation**: Most of these movies are G or PG, which means that they are heavily tilted towards the younger people in the room.
# 9.   **Crime**: These movies are heavily tilted towards R, which means that most of them are designed for people over 17.

# %%
# Extract unique genres and certificates
genres = set(
    genre for movie in ds_movies.keys() \
    for genre in ds_movies[movie]['genre']
)
certificates = set(
    movie[1]['certificate'] for movie in ds_movies.items()
)

# Create a matrix to store the counts of movies
# for each combination of genre and certificate
matrix = np.zeros((len(certificates), len(genres)))

# Populate the matrix with counts
for i, certificate in enumerate(certificates):
    for j, genre in enumerate(genres):
        count = sum(
            1 for movie in ds_movies.items() \
            if movie[1]['certificate'] == certificate \
            and genre in movie[1]['genre']
        )
        matrix[i, j] = count

# Plot the heatmap
plt.figure(figsize=(10, 6))
plt.imshow(matrix, cmap='Blues', interpolation='nearest')

# Add number annotations to each cell
for i in range(len(certificates)):
    for j in range(len(genres)):
        plt.text(
            j, i, str(int(matrix[i, j])),
            ha='center', va='center', color='black'
        )

# Add labels to the axes
plt.xticks(np.arange(len(genres)), genres, rotation=45)
plt.yticks(np.arange(len(certificates)), certificates)

# Add colorbar
plt.colorbar(label='Number of Movies')

# Add title and labels
plt.title('Heatmap of Movies by Genre and Certificate')
plt.xlabel('Genre')
plt.ylabel('Certificate')

# Show plot
plt.show()

# %% [markdown]
# *References*
#
# https://www.geeksforgeeks.org/how-to-select-multiple-columns-in-a-pandas-dataframe/
# https://medium.com/@Shatriya/intro-to-pandas-and-numpy-532a2d5293c8
# https://www.geeksforgeeks.org/create-a-new-column-in-pandas-dataframe-based-on-the-existing-columns/
